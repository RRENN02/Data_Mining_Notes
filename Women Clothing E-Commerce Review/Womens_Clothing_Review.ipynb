# %% [markdown]
# # Women's Online Clothing Feedback

# %% [markdown]
# By: Ahdrian Camilo C. Gernale and James Charles Que

# %% [markdown]
# ## Overview:

# %% [markdown]
# Welcome. This is a Women’s Clothing E-Commerce dataset revolving around the reviews written by customers. Its nine supportive features offer a great environment to parse out the text through its multiple dimensions. Because this is real commercial data, it has been anonymized, and references to the company in the review text and body have been replaced with “retailer”.

# %% [markdown]
# ## Source:

# %% [markdown]
# https://www.kaggle.com/nicapotato/womens-ecommerce-clothing-reviews/download

# %% [markdown]
# ##    Problem:

# %% [markdown]
# How can the feedbacks be useful to other retailers in terms of the rating and recomendations? Can we make a certain pattern to follow up certain customer groups for redesigning clothes?

# %% [markdown]
# ## Objective:

# %% [markdown]
# Make a cluster of customers based on their feedbacks and ratings to make a useful guide in designing clothes

# %% [markdown]
# ## Things to be done:

# %% [markdown]
# 1. Reading and Understanding the Data
# 2. Data Cleaning
# 3. Data Preparation
# 4. Clustering
# 5. Results
# 6. Analysis

# %% [markdown]
# ## Data dictionary

# %% [markdown]
# This dataset includes 23486 rows and 10 feature variables. Each row corresponds to a customer review, and includes the variables:
#
# Variable | Description | Data type
# -------- | ----------- | --------
# Clothing ID | Integer Categorical variable that refers to the specific piece being reviewed.|Numeric
# Age | Positive Integer variable of the reviewers age | Numeric
# Title | String variable for the title of the review | String
# Review Text | String variable for the review body | String
# Rating | Positive Ordinal Integer variable for the product score granted by the customer from 1 Worst, to 5 Best | Numeric
# Recommended IND | Binary variable stating where the customer recommends the product where 1 is recommended, 0 is not recommended | Boolean
# Positive Feedback Count | Positive Integer documenting the number of other customers who found this review positive. | Numeric
# Division Name | Categorical name of the product high level division. | String
# Department Name | Categorical name of the product department name. | String
# Class Name | Categorical name of the product class name | String

# %% [markdown]
# ## Reading of data

# %%
# %pip install nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\K3n\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# %pip install gensim
# %pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/62/27/585859e72e117fe861c2079bcba35591a84f801e21bc1ab85bce6ce60305/scikit_learn-1.6.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading scikit_learn-1.6.1-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=3.1.0 from https://files.pythonhosted.org/packages/4b/2c/ffbf7a134b9ab11a67b0cf0726453cedd9c5043a4fe7a35d1cefa9a1bcfb/threadpoolctl-3.5.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp312-cp312-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.1 MB 5.0 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/11.1 MB 10.5 MB/s eta 0:00:01
#    ------ --------------------------------- 1.8/11.1 MB 14.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.0/11.1 MB 17.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.6/11.1 MB 21.2 MB/s eta 0:00:01
#    --------------------- ------------------ 5.9/11.1 MB 21.1 MB/s eta 0:00:01
#    ------------------------- -------------- 7.2/11.1 MB 23.0 MB/s eta 0:00:01
#    ------------------------------- -------- 8.8/11.1 MB 24.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.9/11.1 MB 24.4 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.1 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.1 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 25.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scikit-learn
# Successfully installed scikit-learn-1.6.1 threadpoolctl-3.5.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import string
import time

# %matplotlib inline


# nltk
import nltk
from nltk.corpus import stopwords
stoplist= stopwords.words('english')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer= WordNetLemmatizer()
from nltk.corpus import wordnet
from sklearn.feature_extraction.text import CountVectorizer

import warnings
warnings.filterwarnings('ignore')

# Enable logging
import logging
logging.basicConfig(level= logging.INFO)

# %%
data = pd.read_csv("data/Womens Clothing E-Commerce Reviews.csv",encoding='utf-8')

# %%
data.head(5)
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
data.describe().T
# Out:
#                            count          mean          std   min      25%  \
# Unnamed: 0               23486.0  11742.500000  6779.968547   0.0  5871.25
# Clothing ID              23486.0    918.118709   203.298980   0.0   861.00
# Age                      23486.0     43.198544    12.279544  18.0    34.00
# Rating                   23486.0      4.196032     1.110031   1.0     4.00
# Recommended IND          23486.0      0.822362     0.382216   0.0     1.00
# Positive Feedback Count  23486.0      2.535936     5.702202   0.0     0.00
#
#                              50%       75%      max
# Unnamed: 0               11742.5  17613.75  23485.0
# Clothing ID                936.0   1078.00   1205.0
# Age                         41.0     52.00     99.0
# Rating                       5.0      5.00      5.0
# Recommended IND              1.0      1.00      1.0
# Positive Feedback Count      1.0      3.00    122.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
data.shape
# Out:
# (23486, 11)

# %%
#checking  null rows
data.Age[data['Review Text'].isnull()].count()
# Out:
# 845

# %%
#checking with unique values
data['Division Name'].unique()
# Out:
# array(['Initmates', 'General', 'General Petite', nan], dtype=object)

# %%
data['Department Name'].unique()
# Out:
# array(['Intimate', 'Dresses', 'Bottoms', 'Tops', 'Jackets', 'Trend', nan],
#       dtype=object)

# %%
data['Class Name'].unique()
# Out:
# array(['Intimates', 'Dresses', 'Pants', 'Blouses', 'Knits', 'Outerwear',
#        'Lounge', 'Sweaters', 'Skirts', 'Fine gauge', 'Sleep', 'Jackets',
#        'Swim', 'Trend', 'Jeans', 'Legwear', 'Shorts', 'Layering',
#        'Casual bottoms', nan, 'Chemises'], dtype=object)

# %%
#Knowing the number of null values of reviews and titles
print('Blank reviews:', data.Age[data['Review Text'].isnull()].count())
print('Blank Titles:', data.Age[data['Title'].isnull()].count())
# Out:
# Blank reviews: 845
# Blank Titles: 3810

# %%
data[data['Review Text'].isnull()].count()
# Out:
# Unnamed: 0                 845
# Clothing ID                845
# Age                        845
# Title                        1
# Review Text                  0
# Rating                     845
# Recommended IND            845
# Positive Feedback Count    845
# Division Name              844
# Department Name            844
# Class Name                 844
# dtype: int64

# %% [markdown]
# Dropping rows with no review text and replace null titles with blanks so that I can run a word count

# %%
rev_data = data[data['Review Text'].notnull()]
rev_data['Title'].fillna('', inplace=True)
rev_data.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33
# 1           1         1080   34
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
#getting the count and mean of the Class Name to know which has more reviews
rev_data.groupby('Class Name').agg({'Rating':['count', 'mean']}).sort_values(by=[('Rating', 'count')], ascending=False)
# Out:
#                Rating
#                 count      mean
# Class Name
# Dresses          6145  4.138812
# Knits            4626  4.145698
# Blouses          2983  4.142809
# Sweaters         1380  4.168841
# Pants            1350  4.261481
# Jeans            1104  4.347826
# Fine gauge       1059  4.237960
# Skirts            903  4.229236
# Jackets           683  4.288433
# Lounge            669  4.301943
# Swim              332  4.171687
# Outerwear         319  4.181818
# Shorts            304  4.253289
# Sleep             214  4.294393
# Legwear           158  4.246835
# Intimates         147  4.278912
# Layering          132  4.348485
# Trend             118  3.838983
# Casual bottoms      1  4.000000
# Chemises            1  4.000000

# %%
#getting the count and mean of the Class Name to know which is most recommended
rev_data.groupby('Class Name').agg({'Recommended IND':['count', 'sum']}).sort_values(by=[('Recommended IND', 'count')], ascending=False)
# Out:
#                Recommended IND
#                          count   sum
# Class Name
# Dresses                   6145  4948
# Knits                     4626  3758
# Blouses                   2983  2406
# Sweaters                  1380  1100
# Pants                     1350  1124
# Jeans                     1104   971
# Fine gauge                1059   882
# Skirts                     903   760
# Jackets                    683   576
# Lounge                     669   574
# Swim                       332   264
# Outerwear                  319   259
# Shorts                     304   255
# Sleep                      214   183
# Legwear                    158   135
# Intimates                  147   126
# Layering                   132   116
# Trend                      118    88
# Casual bottoms               1     1
# Chemises                     1     1

# %%
#getting the count and mean of the Class Name of positive feedback
rev_data.groupby('Class Name').agg({'Positive Feedback Count':['count', 'sum']}).sort_values(by=[('Positive Feedback Count', 'count')], ascending=False)
# Out:
#                Positive Feedback Count
#                                  count    sum
# Class Name
# Dresses                           6145  19510
# Knits                             4626  11598
# Blouses                           2983   8440
# Sweaters                          1380   3154
# Pants                             1350   3327
# Jeans                             1104   2018
# Fine gauge                        1059   2215
# Skirts                             903   2167
# Jackets                            683   1990
# Lounge                             669   1604
# Swim                               332    750
# Outerwear                          319    926
# Shorts                             304    531
# Sleep                              214    399
# Legwear                            158    210
# Intimates                          147    120
# Layering                           132    192
# Trend                              118    401
# Casual bottoms                       1      0
# Chemises                             1      0

# %%
# Pull out individual products and the class they are in
cloth_id = pd.DataFrame(rev_data.groupby(['Clothing ID', 'Class Name']).agg({'Clothing ID':['count']}).sort_values(by=[('Clothing ID', 'count')], ascending=False))

cloth_id[cloth_id['Clothing ID']['count'] > 100]
# Out:
#                        Clothing ID
#                              count
# Clothing ID Class Name
# 1078        Dresses            987
# 862         Knits              778
# 1094        Dresses            735
# 1081        Dresses            561
# 872         Knits              519
# 829         Blouses            512
# 1110        Dresses            471
# 868         Knits              414
# 895         Fine gauge         384
# 936         Sweaters           348
# 867         Knits              333
# 850         Blouses            324
# 1095        Dresses            323
# 863         Knits              291
# 1059        Pants              287
# 1077        Dresses            287
# 1086        Dresses            283
# 1080        Dresses            280
# 860         Knits              276
# 1083        Dresses            244
# 861         Knits              228
# 873         Knits              223
# 1092        Dresses            219
# 828         Blouses            213
# 1033        Jeans              212
# 927         Sweaters           207
# 1056        Pants              206
# 820         Blouses            202
# 836         Blouses            197
# 1022        Jeans              195
# 1072        Dresses            191
# 1008        Skirts             180
# 1104        Dresses            176
# 984         Jackets            166
# 831         Blouses            158
# 1020        Skirts             157
# 833         Blouses            152
# 877         Knits              152
# 854         Knits              145
# 834         Blouses            143
# 1082        Dresses            142
# 864         Knits              141
# 835         Blouses            139
# 1099        Dresses            133
# 1035        Jeans              132
# 865         Knits              127
# 940         Sweaters           126
# 907         Fine gauge         125
# 1087        Dresses            124
# 909         Fine gauge         121
# 1025        Jeans              119
# 875         Knits              115
# 866         Knits              114
# 975         Jackets            113
# 1068        Pants              110
# 830         Blouses            105
# 1037        Jeans              103
# 823         Blouses            102
# 1060        Pants              101

# %%
#Analyzing Product Reviews
cloth_id[cloth_id['Clothing ID']['count'] > 100].plot(title='Individual Product Review Count', legend=False, figsize=(10,6), rot=90)
# Out:
# <Axes: title={'center': 'Individual Product Review Count'}, xlabel='Clothing ID,Class Name'>

# %%
# Checking if the classes of the number of products with reviews > 100 reflects overall numbers
cloth_id[cloth_id['Clothing ID']['count'] >100].groupby('Class Name').agg({('Clothing ID', 'count'):['count', 'sum']})
# Out:
#            Clothing ID
#                  count
#                  count   sum
# Class Name
# Blouses             11  2247
# Dresses             15  5156
# Fine gauge           3   630
# Jackets              2   279
# Jeans                5   761
# Knits               14  3856
# Pants                4   704
# Skirts               2   337
# Sweaters             3   681

# %%
#Showing the distributiono of Reviewer's Age
rev_data[('Age')].hist()
# Out:
# <Axes: >

# %%
#Curious about the number of reviewers above and below 43 yrs old
print ('Number below average of 43: ', rev_data.Age[rev_data['Age'] < 43].count())
print ('Number 43 & above: ', rev_data.Age[rev_data['Age'] >= 43].count())
# Out:
# Number below average of 43:  12111
# Number 43 & above:  10530

# %%
#Plotting rating
rev_data[('Rating')].hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Observations:
# The 3 category names, Division, Department and Class, seem similar but Class seems the most extensive in terms of range of values and may help to provide analysis once clusters have been formed.
#
# Within Class, over a quarter of reviews are for dresses, with the other large groups being knits and blouses. These 3 classes make up over half of the reviews.
#
# Average ratings for classs are just over 4 for nearly all categories except Trend which is 3.8. Perhaps the clothes are seen as not trendy? Something to look out for.
#
# The recommended indicator merely follows the ratings so doesn't offer much new information.
#
# Feedback count of other customers finding reviews positive, is higher per review for the higher categories, with
#
# Dresses with the largest ratio of over 3. The ratio drops slightly as the number of reviews drops, again until Trend where the ratio is also high. Interesting, but probably not much use at this stage (though might help to understand what makes a positive review if that was required?).
#
# Age range is from 18 to 99, with the average being 43 and median 41. This might tell us something about the sorts of things that this age group are concerned about. There is a slight skew towards being younger than the average - 12.5k against around 11k above.
#
# Ratings and recommendation indicator give us an idea of sentiment, and may help with analysis post clustering, although I am looking for insights outside of just sentiment.
#
# Clothing ID shows the unique products. In total there are ~1200 products being reviewed, but nearly 500 of these have just a single review. 162 products have a review count greater than 20, with ~60 prods > 100 reviews. If the actual product were known, the resulting clusters could be grouped by product for feedback.
#
# Of the top reviewed products by volume, the top 3 are in the Classes expected - dresses, knits and blouses.
#
# A low number of products are responsible for most of the reviews:
#
# Dresses: 5156 of 6145 revs from 15 prods - 84%
#
# Knits: 3856 of 4626 revs from 14 prods - 83%
#
# Blouses 2247 of 2983 revs from 11 prods - 75%
#
# So nearly 50% of all reviews is from just 40 products
#
# Assuming that this data represents reviews for all products, the above implies to me that these are the top sellers and get more reviews as more people have bought them. But it could imply that these are the most popular, despite sales. Either way, this retailer has 0.03% of its products making all the buzz. Some initial feedback could be to reduce the product line!
#
# For my purposes here, this again might mean that the breadth of language and what is being talked about is limited. This might be useful giving distinct clusters, or it might mean that clusters are hard to define as language is "homogonous" and we can't distinguish one thing from another.

# %% [markdown]
# ### Analyzing Reviews (by word count)

# %%
rev_data['Title Word Count'] = rev_data['Title'].map(lambda x: len(x.split()))
rev_data['Review Word Count'] = rev_data['Review Text'].map(lambda x: len(x.split()))
len(rev_data)
# Out:
# 22641

# %%
plot = rev_data[('Review Word Count')].plot(kind="hist")
plot.set_xlabel("Word Count")
plot.set_ylabel("Number of Reviews")
# Out:
# Text(0, 0.5, 'Number of Reviews')

# %%
rev_data['Review Word Count'].describe()
# Out:
# count    22641.000000
# mean        60.196679
# std         28.534612
# min          2.000000
# 25%         36.000000
# 50%         59.000000
# 75%         88.000000
# max        115.000000
# Name: Review Word Count, dtype: float64

# %%
rev_data.boxplot(column='Review Word Count', by='Class Name', figsize=(12,12), rot=45)
# Out:
# <Axes: title={'center': 'Review Word Count'}, xlabel='Class Name'>

# %%
rev_data.boxplot(column='Review Word Count', by='Rating')
# Out:
# <Axes: title={'center': 'Review Word Count'}, xlabel='Rating'>

# %%
rev_data['Title Word Count'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Text Observations
#
# Removing reviews with no text has reduced numbers by just over 800 and seems fairly random across age.
#
# Word counts for the reviews are mainly 30-100 words, which is about 4 - 12 lines. Enough for a few sentences in each. There are around 700 short reviews, < 30 words, and around 500 long reviews, > 100. I don't forsee this as a problem but worth bearing in mind after clustering in case there is an impact.
#
# These might be outliers, but we need to keep them in at this stage.
#
# Distribution of word count seems fairly normal with a spike for reviews of around 100 words and mean of 60.
#
# Titles are much shorter. We thought we'd check to see if there might be some meaning to glean here but we think the text is too short, so will ignore for now.

# %% [markdown]
# ### Checking on some reviews

# %%
pd.set_option('display.max_colwidth', True)
rev_data['Review Text'].sample(n=100)
# Out:
# 16242    Oh how i love moth sweaters but wow was this one a disappointment. the color is wonderful, the shape is unique and the stitch work is lovely but that's where the compliments end. it's an itchy, cheap feeling acrylic that is too short for my torso. i am truly disappointed that at this price point it was such a cheap feeling piece. so bummed. so so bummed.
# 2613     This shirt is the perfect go-to; classic white button down, with a twist! the fit is flattering & i would have to say runs a little large. i am 5'4,124 lbs, broad shoulders, with a 36d bust and bought the 2 (outside of retailer, a 36d usually needs about an 8). i was worried what may happen when i wash it because it fits perfectly but i washed it in cold & hung it up to dry & it was fine.
# 10126    This looks nothing like it does on the website. it runs small and the colors are so muddy. it doesn't drape nicely and i a musually an xs and this was short, stiff and plain ugly. sent it back immediately.
# 7684     After a rough day at the office, i went into my local retailer to seek out some retail therapy. i stumbled upon this skirt and knew i had to try it on. though it's more than i normally like to spend, it was well worth the price. material is lightweight and comfortable yet substantial enough for work. fit is spot on (i have wider hips and a smaller waist, which typically makes me a size 12 and that's what i bought). the color is a gorgeous mustard yellow that can be paired with all sorts of colors,
# 1833     I love this top! fits true to size. tunic length, thin comfy fabric, adorable subtle print. the perfect top!
#                                                              ...
# 15979    I went with the xs because i didn't want the v neck in the front to be too low. it looks cute paired with a kimono and a necklace.
# 8482     I bought this top in black n moss. they are of a great quality n love that u don't need a cami under. i do like them very much except that they're a lil too billowy in front for me. when i gathered excess material on the sides it looked much better. the black didn't look as large...black is slimming. i love the neck and the material. haven't decided yet if i'm keeping or returning.
# 15160    Nice fit, wish it was a little longer but i really do like it and feel good when i wear it
# 17952    I'll admit, i had a lot of sticker shock when i saw this was a moth sweater coat at this price point. but i was immediately drawn to it. this is a one of a kind piece for sure. the colors are vibrant, the design is stylish and it is beautifully unstructured. it has a cocoon shape, wool on the outside and a soft knit on the inside. its a bit heavier (as you would expect a wool coat to be.) my absolute favorite part is the print. very classic on top, and very boho on bottom. it is gorgeous. i woul
# 14010    I ordered the dress on-line. this dress looked pretty, the material was soft and comfortable, the length was perfect, but the zipper was totally out of place. it bulged out in a weird way which made it look like the dress was torn. i had to return the dress. i normally don't see a problem at this level in retailer clothes.
# Name: Review Text, Length: 100, dtype: object

# %% [markdown]
# ### Initial Thoughts on Text
#
# There is a lot of positive text and this is borne out by the number of positive ratings. We'll look further into the breakdown. Our worry is that this will give the language all of the same feel, so clusters might be large and indistinct.
#
# The fact that the ratings are mainly about dresses, knitwear and blouses might also restrict the breadth of expression. But we will see.
#
# We can also observe reviews contain multiple sentences, and these sentences themselves often contain more than one area of attention.
#
# For example, in this review extract:
#
#     it was soft and cuddly, but a little baggy under the arms, and it shed everywhere.
#
# This can be broken down into:
#
#     it was soft and cuddly
#
#     a little baggy under the arms
#
#     it shed everywhere
#
# These make for nice discreet categories, so if the clustering algorithm can identify these and we allow a review to be in more than one cluster, then hopefully we'll see something like these. Splitting at sentence level might make sense in terms of reading clusters (rather than at review level) but splitting a sentence out might be harder as it isn't always obvious where the split of a sentence's meaning lies.

# %%
def percentage(part, whole):
  return 100 * float(part)/float(whole)

# %%
total_rec_cnt = rev_data.Rating.count()
rate_4_above = rev_data.Rating[rev_data['Rating'] > 3].count()
rate_3_below = rev_data.Rating[rev_data['Rating'] < 4].count()
rate_2_below = rev_data.Rating[rev_data['Rating'] < 3].count()
rate_4_above_perc = percentage(rate_4_above, total_rec_cnt)
rate_3_below_perc = percentage(rate_3_below, total_rec_cnt)
rate_2_below_perc = percentage(rate_2_below, total_rec_cnt)

print ('Total number of ratings {}. '.format(total_rec_cnt))

print ('Number of ratings 4 and above {}. Percentage of Total: {:.2f}'.format(rate_4_above, rate_4_above_perc))
print ('Number of ratings 3 and below {}. Percentage of Total: {:.2f}'.format(rate_3_below, rate_3_below_perc))
print ('Number of ratings 2 and below {}. Percentage of Total: {:.2f}'.format(rate_2_below, rate_2_below_perc))
# Out:
# Total number of ratings 22641.
# Number of ratings 4 and above 17448. Percentage of Total: 77.06
# Number of ratings 3 and below 5193. Percentage of Total: 22.94
# Number of ratings 2 and below 2370. Percentage of Total: 10.47

# %%
# Pull out individual products that are low rated and the class they are in
cloth_id_low_rate = pd.DataFrame(rev_data[rev_data['Rating'] < 3].groupby(['Clothing ID', 'Class Name']).agg({'Clothing ID':['count']}).sort_values(by=[('Clothing ID', 'count')], ascending=False))

cloth_id_low_rate
# Out:
#                        Clothing ID
#                              count
# Clothing ID Class Name
# 1078        Dresses     91
# 862         Knits       83
# 1094        Dresses     70
# 868         Knits       62
# 829         Blouses     51
# ...                     ..
# 706         Lounge      1
# 719         Lounge      1
# 743         Intimates   1
# 757         Intimates   1
# 1195        Dresses     1
#
# [386 rows x 1 columns]

# %%
# See if the classes of products rated 1 have just 1 review as well
# To see if negative reviews are on their own with no positives to balance them
cloth_id_low_rate[cloth_id_low_rate['Clothing ID']['count'] == 1].groupby('Class Name').agg({('Clothing ID', 'count'):['count', 'sum']})
# Out:
#            Clothing ID
#                  count
#                  count sum
# Class Name
# Blouses     4           4
# Dresses     9           9
# Fine gauge  11          11
# Intimates   10          10
# Jackets     13          13
# Jeans       6           6
# Knits       3           3
# Layering    8           8
# Legwear     4           4
# Lounge      30          30
# Outerwear   4           4
# Pants       9           9
# Shorts      8           8
# Skirts      3           3
# Sleep       19          19
# Sweaters    7           7
# Swim        20          20
# Trend       6           6

# %% [markdown]
# We checked to see if the low ratings (1 or 2) were the only review for a product, in case this might make the text "outliers" in the sense that they are a standalone criticism with no balance of a positive review. 172 products with a single review have a low rating, around a third of the products with a single rating. This is 3 times higher than the low rating across all products of 10%.
#
# But it's less than 10% of all low rated reviews. So whilst a lot of single review products have a higher chance of having a low rating (and more negative language) this doesn't represent a significant portion of the low rating text.
#
# The losers with single ratings which are low are Loungewear, Swimwear and Sleepwear.

# %% [markdown]
# ## Cleaning of Data

# %% [markdown]
# Checking for special characters like:
#
#     * html - various tags
#     * editor instructions like \n \r
#
# Item Count
#
#     \n - 2024
#
#     \r - 1398
#
#     "<" - 8
#
#     ">" - 6
#
# html head - 0

# %%
import re
def re_check_slash(text):
    return re.findall(r'(\n|\r|\t|\f)', text)

# %%
# Check for control characters
all_checks = []
for rev in rev_data['Review Text']:
    all_checks += re_check_slash(rev)

# Convert list to set of unique values
set(all_checks)
# Out:
# {'\n', '\r'}

# %% [markdown]
# ### Text Analysis
#
# Here we will explore the text in more detail looking for patterns and any common words and expressions.

# %%
rev_data[rev_data.duplicated(subset='Review Text')]
# Out:
#        Unnamed: 0  Clothing ID  Age                                  Title  \
# 10067  10067       1171         26   Love retailer bathing suits!
# 11074  11074       628          60   Cute cover-up or summer top & shorts!
# 12526  12526       1081         42   Beautiful dress, fits horribly
# 13354  13354       393          26   Love retailer bathing suits!
# 14275  14275       879          43   Love this shirt
# 21470  21470       895          60   Soft & beautiful!
# 21888  21888       1022         37
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Review Text  \
# 10067  Perfect fit and i've gotten so many compliments. i buy all my suits from here now!
# 11074  Lightweight, soft cotton top and shorts. i think it's meant to be a beach cover-up but i'm wearing it as a thin, light-weight summer outfit on these hot hot days. the top has a loose elastic around the bottom which i didn't realize when i ordered it, but i like it and it matches the look in the photos. and the shorts are very low-cut - don't expect them up around your waist. again, i like that. some might want to wear a cami underneath because it's a thin cotton but i'm fine as-is. i bought it i
# 12526  I purchased this and another eva franco dress during retailer's recent 20% off sale. i was looking for dresses that were work appropriate, but that would also transition well to happy hour or date night. they both seemed to be just what i was looking for. i ordered a 4 regular and a 6 regular, as i am usually in between sizes. the 4 was definitely too small. the 6 fit, technically, but was very ill fitting. not only is the dress itself short, but it is very short-waisted. i am only 5'3", but it fe
# 13354  Perfect fit and i've gotten so many compliments. i buy all my suits from here now!
# 14275  I bought this shirt at the store and after going home and trying it on, i promptly went online and ordered two more! i've gotten multiple compliments anytime i wear any of them. great for looking put together with no fuss. \r\npeople that have commented there's were destroyed in the wash didn't read the care label which says dry clean.
# 21470  The sweater and skirt are so pretty! they're really soft and have such an easy, comfortable look together. really love this gorgeous outfit.\n\ni am borderline small/medium and kept the size small after trying both on.
# 21888  Love, love these jeans. being short they come right to my ankle. super soft and don?t require any hemming. i ordered my typical jean size of 26 and they fit like a glove. would love to have these in black and grey.
#
#        Rating  Recommended IND  Positive Feedback Count   Division Name  \
# 10067  5       1                0                        Initmates
# 11074  5       1                2                        Initmates
# 12526  2       0                3                        General
# 13354  5       1                0                        Initmates
# 14275  5       1                0                        General Petite
# 21470  5       1                5                        General Petite
# 21888  5       1                0                        General
#
#       Department Name  Class Name  Title Word Count  Review Word Count
# 10067  Intimate        Swim        4                 16
# 11074  Intimate        Lounge      7                 98
# 12526  Dresses         Dresses     4                 96
# 13354  Intimate        Swim        4                 16
# 14275  Tops            Knits       3                 60
# 21470  Tops            Fine gauge  3                 36
# 21888  Bottoms         Jeans       0                 42

# %%
undata = rev_data.drop_duplicates(subset='Review Text')

# %%
import string
import nltk
import nltk.data
#nltk.download()   

from nltk import data, bigrams
# from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer

# %%
# A few standard operations on the text to get to words that add value

def scrub_text(text,
               html=False,
               hyphen=False,
               stemmer=False,
               stopwords=False,
               punctuation=False,
               lem=False,
               w2v=False):
    """Return cleaned up text."""
    if html:
        text = BeautifulSoup(text).get_text()  # Deal with HTML

    if hyphen:
        text = ' '.join(re.split('[-]+', text)) # Split out hyphenated words 
    
    text = re.sub('\.(?!\s)(?!$)', '. ', text) # Add space after "."
    
    word_tokens = word_tokenize(text.lower())
    if punctuation:
        word_tokens = [word for word in word_tokens if word not in punctuation]
    word_tokens = [word for word in word_tokens if word.isalnum()]
    word_tokens = [word for word in word_tokens if not word.isdigit()]
    
    if stopwords:
        word_tokens = [word for word in word_tokens if word not in stopwords]
    
    if lem:
        word_tokens = [lem.lemmatize(word) for word in word_tokens]
    
    if stemmer:
        word_tokens=[stemmer.stem(word) for word in word_tokens]
    
    if w2v:
        return word_tokens
    else:
        return ' '.join(word_tokens)

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\K3n\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# clean text - tokenize, remove stopwords & punctuation but don't stem or lem

#lem = nltk.WordNetLemmatizer()
#stemmer = SnowballStemmer("english")
sw = stopwords.words('english')
punctuation=set(list(string.punctuation))

undata['cleantxt'] = undata['Review Text'].map(lambda x: scrub_text(x,
                                                                    hyphen=True,
                                                                    stopwords=sw,
                                                                    punctuation=punctuation))

# %%
undata.head(5)
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0  0           767          33
# 1  1           1080         34
# 2  2           1077         60   Some major design flaws
# 3  3           1049         50   My favorite buy!
# 4  4           847          47   Flattering shirt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Review Text  \
# 0  Absolutely wonderful - silky and sexy and comfortable
# 1  Love this dress!  it's sooo pretty.  i happened to find it in a store, and i'm glad i did bc i never would have ordered it online bc it's petite.  i bought a petite and am 5'8".  i love the length on me- hits just a little below the knee.  would definitely be a true midi on someone who is truly petite.
# 2  I had such high hopes for this dress and really wanted it to work for me. i initially ordered the petite small (my usual size) but i found this to be outrageously small. so small in fact that i could not zip it up! i reordered it in petite medium, which was just ok. overall, the top half was comfortable and fit nicely, but the bottom half had a very tight under layer and several somewhat cheap (net) over layers. imo, a major design flaw was the net over layer sewn directly into the zipper - it c
# 3  I love, love, love this jumpsuit. it's fun, flirty, and fabulous! every time i wear it, i get nothing but great compliments!
# 4  This shirt is very flattering to all due to the adjustable front tie. it is the perfect length to wear with leggings and it is sleeveless so it pairs well with any cardigan. love this shirt!!!
#
#    Rating  Recommended IND  Positive Feedback Count   Division Name  \
# 0  4       1                0                        Initmates
# 1  5       1                4                        General
# 2  3       0                0                        General
# 3  5       1                0                        General Petite
# 4  5       1                6                        General
#
#   Department Name Class Name  Title Word Count  Review Word Count  \
# 0  Intimate        Intimates  0                 8
# 1  Dresses         Dresses    0                 62
# 2  Dresses         Dresses    4                 98
# 3  Bottoms         Pants      3                 22
# 4  Tops            Blouses    2                 36
#
#                                                                                                                                                                                                                                                                                                        cleantxt
# 0  absolutely wonderful silky sexy comfortable
# 1  love dress sooo pretty happened find store glad bc never would ordered online bc petite bought petite love length hits little knee would definitely true midi someone truly petite
# 2  high hopes dress really wanted work initially ordered petite small usual size found outrageously small small fact could zip reordered petite medium overall top half comfortable fit nicely bottom half tight layer several somewhat cheap net layers imo major design flaw net layer sewn directly zipper c
# 3  love love love jumpsuit fun flirty fabulous every time wear get nothing great compliments
# 4  shirt flattering due adjustable front tie perfect length wear leggings sleeveless pairs well cardigan love shirt

# %%
# Build a list of all words from reviews in order to create a corpus

def create_corpus(data, text_field):
    """Return NLTK text corpus."""
    cnt = 0 
    build_text = []
    for row in data[text_field]:
        token = word_tokenize(row)
        build_text.extend(token)
        cnt += 1
        if cnt % 5000 == 0:
            print("Docs processed:", cnt)

    corp = nltk.Text(build_text)
    return corp, build_text

# %%
corp_data, tokens = create_corpus(undata, 'cleantxt')
# Out:
# Docs processed: 5000
# Docs processed: 10000
# Docs processed: 15000
# Docs processed: 20000

# %%
len(tokens)
# Out:
# 635819

# %%
freq_dist = nltk.FreqDist(corp_data)
freq_dist.most_common(50)
# Out:
# [('dress', 10539),
#  ('love', 8945),
#  ('size', 8751),
#  ('top', 7393),
#  ('fit', 7300),
#  ('like', 7144),
#  ('wear', 6433),
#  ('great', 6114),
#  ('would', 5429),
#  ('fabric', 4787),
#  ('small', 4673),
#  ('color', 4582),
#  ('look', 4028),
#  ('really', 3923),
#  ('ordered', 3846),
#  ('little', 3775),
#  ('perfect', 3770),
#  ('one', 3635),
#  ('flattering', 3515),
#  ('well', 3390),
#  ('soft', 3332),
#  ('back', 3214),
#  ('comfortable', 3055),
#  ('cute', 3041),
#  ('nice', 3020),
#  ('bought', 2983),
#  ('beautiful', 2964),
#  ('looks', 2873),
#  ('bit', 2866),
#  ('fits', 2853),
#  ('large', 2815),
#  ('shirt', 2808),
#  ('material', 2760),
#  ('much', 2709),
#  ('length', 2672),
#  ('also', 2587),
#  ('sweater', 2512),
#  ('long', 2460),
#  ('got', 2426),
#  ('could', 2384),
#  ('jeans', 2372),
#  ('colors', 2360),
#  ('petite', 2339),
#  ('waist', 2326),
#  ('quality', 2290),
#  ('medium', 2231),
#  ('pretty', 2192),
#  ('think', 2185),
#  ('even', 2172),
#  ('retailer', 2157)]

# %%
top_words = pd.DataFrame(freq_dist.most_common(10), columns=('Word', 'Count'))
top_words
# Out:
#      Word  Count
# 0  dress   10539
# 1  love    8945
# 2  size    8751
# 3  top     7393
# 4  fit     7300
# 5  like    7144
# 6  wear    6433
# 7  great   6114
# 8  would   5429
# 9  fabric  4787

# %% [markdown]
# #### Plot of word count in Review Text

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

freq_dist.plot(20,cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
# calculate bigrams
terms_bigram = bigrams(tokens)
bi_fdist = nltk.FreqDist(terms_bigram)
top_bigrams = pd.DataFrame(bi_fdist.most_common(50), columns=('Word Pair', 'Count'))
top_bigrams
# Out:
#               Word Pair  Count
# 0   (true, size)         1343
# 1   (love, dress)        748
# 2   (usually, wear)      690
# 3   (looks, great)       622
# 4   (well, made)         606
# 5   (fit, perfectly)     604
# 6   (love, top)          571
# 7   (size, small)        524
# 8   (fits, perfectly)    486
# 9   (usual, size)        479
# 10  (love, love)         435
# 11  (look, like)         412
# 12  (looks, like)        397
# 13  (fit, well)          380
# 14  (highly, recommend)  365
# 15  (many, compliments)  364
# 16  (super, cute)        363
# 17  (runs, large)        363
# 18  (wear, size)         359
# 19  (feel, like)         348
# 20  (fit, great)         348
# 21  (fabric, soft)       347
# 22  (ordered, size)      346
# 23  (soft, comfortable)  339
# 24  (ca, wait)           336
# 25  (normally, wear)     331
# 26  (super, soft)        330
# 27  (size, fit)          329
# 28  (skinny, jeans)      322
# 29  (wanted, love)       322
# 30  (even, though)       318
# 31  (absolutely, love)   315
# 32  (fit, perfect)       313
# 33  (really, like)       302
# 34  (regular, size)      300
# 35  (going, back)        295
# 36  (looked, like)       291
# 37  (look, great)        284
# 38  (ordered, small)     282
# 39  (fits, well)         282
# 40  (really, cute)       281
# 41  (runs, small)        279
# 42  (fits, true)         279
# 43  (material, soft)     276
# 44  (high, quality)      266
# 45  (normal, size)       263
# 46  (wait, wear)         260
# 47  (one, size)          256
# 48  (fit, like)          254
# 49  (good, quality)      245

# %%
corp_data.similar('dress')
# Out:
# top fit shirt love color sweater fabric size skirt really colors great
# flattering one would comfortable look perfect small pants

# %%
corp_data.concordance('back')
# Out:
# Displaying 25 of 3214 matches:
# istmas dress year needless say going back dress perfection pretty flattering f
# pregnant bough medium grow tie front back provides nice flexibility form fitti
# kirt portion pretty poofy keep going back forth mainly price although quality
# p wear leggings bought slip wore tie back rocked white wedges could also wear
# aned ordered months ago finally came back order huge disappointment fit much i
# le still worth paid definitely going back neat dress color great fabric super
#  pilcro stet jeans flattering peplum back nice cut shoulders neckline pretty u
# nerally wear small fit well probably back black bought item online fit model l
# loose got mine seemed bit tight took back store ordered larger size sale price
# tty unusual look great slight peplum back hangs nicely lightweight tee fabric
# es though tank fit well loved ruffle back layed front good look retuning got p
# lor nice lines downside retailer tag back itchy need remove dress simply beaut
# rfect could happier purchase keyhole back beautiful detail tags sewn small lon
# eckline higher used also two buttons back must unbuttoned order wear top diffi
# ally fancy tshirt summer might bring back alone since originally planned wear
# d looser one photo looks like pinned back usually wear medium large got medium
# cide need petite looked huge pinched back see xxs would work lot fabric looser
#  get tried fit fine lacked something back little bit long front little bit sho
# nt daughter saw try said piece going back excited order top red xs cute huge s
#  cute huge shapeless support thin go back looked reviews need easy comfortable
# ble shirt felt like pajama top going back first sure neckline much lower wavy
# really long almost touches top knees back sooooo pretty though shirt exactly p
# ordered petite xs liked length front back well side high liking tie part hit p
#  item received undoubtedly one going back dear retailer please make sure send
# look unflattering overall return one back store color perfect fall winter insi

# %% [markdown]
# ### More thoughts on text
#
# As expected, the top words appearing are for dress and love - very positive! Followed by size, top, fit and like. This isn't revealing much beyond what we'd expect with reviews on womens clothes. Fabric and color are around the 10th position and probably the first words I'd rate as carrying some meaning that might useful feedback.
#
# Ordered appears around 15th which might indicate some feedback on the ordering process.
#
# Lots of words about attributes of clothes and sizes.
#
# **Again, collocations reveal some positive pairings if words like fits perfectly and highly recommended! "Going back" and "full price" stand out as possible negatives that occur though price isn't mentioned in the top 50 pairings but going back does have nearly 300 mentions.

# %%
corp_data.common_contexts(['going', 'back'])
# Out:
# small_order one_get detail_front could_back one_home detail_fabric
# back_back longer_wearing way_keep

# %%
undata['Rating'][undata['Review Text'].str.contains('going', 'back')].hist()
# Out:
# <Axes: >

# %%
print(undata['Rating'][undata['Review Text'].str.contains('going', 'back')].count())
print(undata['Rating'][undata['Review Text'].str.contains('going', 'back')].value_counts())
# Out:
# 1138
# Rating
# 5    434
# 4    242
# 3    229
# 2    164
# 1    69
# Name: count, dtype: int64

# %%
print(undata['Rating'][undata['Review Text'].str.contains('ordered')].count())
print(undata['Rating'][undata['Review Text'].str.contains('ordered')].value_counts())
# Out:
# 3405
# Rating
# 5    1598
# 4    827
# 3    513
# 2    318
# 1    149
# Name: count, dtype: int64

# %% [markdown]
# Text containing 'going' and 'back' has much lower ratings - about 20% 1 or 2, compared with overall of 10%.
#
# Ordered is less than overall at just under 14% low ratings.

# %%
corp_data.similar('ordered')
# Out:
# bought got size tried purchased love small dress usually petite went
# wear medium top true perfect fit order regular xs

# %%
# Review word count
undata['rev_word_count']= undata['Review Text'].apply(lambda x: len(x.strip().split()))

# Unique word count
undata['unique_word_count']= undata['Review Text'].apply(lambda x: len(set(str(x).split())))

# %%
undata.columns
# Out:
# Index(['Unnamed: 0', 'Clothing ID', 'Age', 'Title', 'Review Text', 'Rating',
#        'Recommended IND', 'Positive Feedback Count', 'Division Name',
#        'Department Name', 'Class Name', 'Title Word Count',
#        'Review Word Count', 'cleantxt', 'rev_word_count', 'unique_word_count'],
#       dtype='object')

# %%
# Bucketing Clothing ID's with 1 or 2 count

clothing_id_to_combine=[]
for val, cnt in undata['Clothing ID'].value_counts().items():
    # If that Clothing_ID is present less than 1%(~200) of the total data, club it into '000' (default) id
    if(cnt<200):         
        clothing_id_to_combine.append(val)        

print("# of clothing ID's clubbed: ",len(clothing_id_to_combine))

undata['new_clothingID']= undata['Clothing ID'].apply(lambda x: '000' if x in clothing_id_to_combine else x)
undata.new_clothingID.value_counts(normalize=True)
# Out:
# # of clothing ID's clubbed:  1149
# new_clothingID
# 000     0.542944
# 1078    0.043607
# 862     0.034373
# 1094    0.032473
# 1081    0.024742
# 872     0.022930
# 829     0.022621
# 1110    0.020809
# 868     0.018291
# 895     0.016921
# 936     0.015375
# 867     0.014712
# 850     0.014315
# 1095    0.014271
# 863     0.012857
# 1077    0.012680
# 1059    0.012680
# 1086    0.012503
# 1080    0.012371
# 860     0.012194
# 1083    0.010780
# 861     0.010073
# 873     0.009852
# 1092    0.009676
# 828     0.009411
# 1033    0.009366
# 927     0.009146
# 1056    0.009101
# 820     0.008925
# Name: proportion, dtype: float64

# %% [markdown]
# ## Clustering

# %% [markdown]
# First use a KMeans model for a benchmark.
#
# Break out reviews to sentences.
#
# Need to do some pre-processing which can be used for the main model too.

# %%
# Review word count
undata['rev_word_count']= undata['Review Text'].apply(lambda x: len(x.strip().split()))

# Unique word count
undata['unique_word_count']= undata['Review Text'].apply(lambda x: len(set(str(x).split())))

# %%
# Bucketing Clothing ID's with 1 or 2 count

clothing_id_to_combine=[]
for val, cnt in undata['Clothing ID'].value_counts().items():
    # If that Clothing_ID is present less than 1%(~200) of the total data, club it into '000' (default) id
    if(cnt<200):         
        clothing_id_to_combine.append(val)        

print("# of clothing ID's clubbed: ",len(clothing_id_to_combine))

undata['new_clothingID']= undata['Clothing ID'].apply(lambda x: '000' if x in clothing_id_to_combine else x)
undata.new_clothingID.value_counts(normalize=True)
# Out:
# # of clothing ID's clubbed:  1149
# new_clothingID
# 000     0.542944
# 1078    0.043607
# 862     0.034373
# 1094    0.032473
# 1081    0.024742
# 872     0.022930
# 829     0.022621
# 1110    0.020809
# 868     0.018291
# 895     0.016921
# 936     0.015375
# 867     0.014712
# 850     0.014315
# 1095    0.014271
# 863     0.012857
# 1077    0.012680
# 1059    0.012680
# 1086    0.012503
# 1080    0.012371
# 860     0.012194
# 1083    0.010780
# 861     0.010073
# 873     0.009852
# 1092    0.009676
# 828     0.009411
# 1033    0.009366
# 927     0.009146
# 1056    0.009101
# 820     0.008925
# Name: proportion, dtype: float64

# %% [markdown]
# Calibrating Title and Review sentiment scores using VADER Sentiment!
# VADER (Valence Aware Dictionary and sentiment Reasoner) is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media.

# %%
# %pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Obtaining dependency information for vaderSentiment from https://files.pythonhosted.org/packages/76/fc/310e16254683c1ed35eeb97386986d6c00bc29df17ce280aed64d55537e9/vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Collecting requests (from vaderSentiment)
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/f9/9b/335f9764261e915ed497fcdeb11df5dfd6f7bf257d4a6a2a686d80da4d54/requests-2.32.3-py3-none-any.whl.metadata
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests->vaderSentiment)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/21/5b/1b390b03b1d16c7e382b561c5329f83cc06623916aab983e8ab9239c7d5c/charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests->vaderSentiment)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/76/c6/c88e154df9c4e1a2a66ccf0005a88dfb2650c1dffb6f5ce603dfbd452ce3/idna-3.10-py3-none-any.whl.metadata
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->vaderSentiment)
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/c8/19/4ec628951a74043532ca2cf5d97b7b14863931476d117c471e8e2b1eb39f/urllib3-2.3.0-py3-none-any.whl.metadata
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->vaderSentiment)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/38/fc/bce832fd4fd99766c04d1ee0eead6b0ec6486fb100ae5e74c1d91292b982/certifi-2025.1.31-py3-none-any.whl.metadata
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ---------------------------------------- 0.0/126.0 kB ? eta -:--:--
#    ---------------------------------------- 126.0/126.0 kB 3.6 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB ? eta 0:00:00
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#    ---------------------------------------- 0.0/166.4 kB ? eta -:--:--
#    --------------------------------------- 166.4/166.4 kB 10.4 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
#    ---------------------------------------- 0.0/102.8 kB ? eta -:--:--
#    ---------------------------------------- 102.8/102.8 kB ? eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ---------------------------------------- 0.0/70.4 kB ? eta -:--:--
#    ---------------------------------------- 70.4/70.4 kB 3.8 MB/s eta 0:00:00
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ---------------------------------------- 0.0/128.4 kB ? eta -:--:--
#    ---------------------------------------- 128.4/128.4 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests, vaderSentiment
# Successfully installed certifi-2025.1.31 charset-normalizer-3.4.1 idna-3.10 requests-2.32.3 urllib3-2.3.0 vaderSentiment-3.3.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\K3n\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer= SentimentIntensityAnalyzer()

# Try it out!
vs= analyzer.polarity_scores("Vader sentiment looks interesting, I have high hopes!")
print(vs)
# Out:
# {'neg': 0.0, 'neu': 0.509, 'pos': 0.491, 'compound': 0.6996}

# %% [markdown]
# The compound score obtained from valence scores is computed by summing the valence scores of each word in the lexicon, adjusted according to the rules, and then normalized to be between -1 (most extreme negative) and +1 (most extreme positive). This is the most useful metric if you want a single unidimensional measure of sentiment for a given sentence. Calling it a 'normalized, weighted composite score' is accurate.

# %%
undata['review_sentiment']= [analyzer.polarity_scores(line)['compound'] for line in undata['Review Text']]

# %%
undata.review_sentiment.head(5)
# Out:
# 0    0.8932
# 1    0.9729
# 2    0.9208
# 3    0.5727
# 4    0.9291
# Name: review_sentiment, dtype: float64

# %% [markdown]
# After analyzing certain Title sentiments, we notice that titles with 0 scores consist of positive, negative and neutral sentiments:
#
# Negative sentiments with 0 score:
#    * Falls flat >>>>> 0.0
#    * Runs short >>>>> 0.0
#
# Positive sentiments with 0 score:
#    * Must have >>>>> 0.0
#    * Comfy >>>>> 0.0
#    * Stylish and versatile! >>>>> 0.0
#
# Neutral sentiments with 0 score:
#    * Simple, stylish, lovely-runs a bit big >>>>> 0.0
#    * Some things you should know... >>>>> 0.0
#    * Mehh >>>>> 0.0
#    * Neutral blue >>>>> 0.0
#
# Hence we have assigned score '0.0' score to 'No title' above.

# %%
# Title provides extra insight of the sentiment of the customer while writing the review. Hence we will also obtain Title sentiment alongwith review sentiment score.
# However 13% reviews don't have a Title. Hence filling in the null values with 'no title' and assigning it 0(neutral) sentiment

undata.Title.fillna('no title', inplace=True)
undata['title_sentiment']= undata['Title'].apply(lambda x: analyzer.polarity_scores(x)['compound'] if str(x)!= 'no title' else 0.0)

for index, row in undata[100:120].iterrows():
    print(row['Title']," >>>>>", row['title_sentiment'])
# Out:
# Not a fan  >>>>> -0.2411
#   >>>>> 0.0
# Excited ... but ...  >>>>> 0.1779
# Beautiful shirt but runs small!  >>>>> 0.4102
# Beautiful  >>>>> 0.5994
# Perfect fall shirt!  >>>>> 0.6114
#   >>>>> 0.0
# Poor quality  >>>>> -0.4767
# An almost for me...  >>>>> 0.0
# Beautiful, stunning, cozy top!  >>>>> 0.8221
# Cute and comfy  >>>>> 0.4588
# Disappointing quality  >>>>> -0.4939
# Cute tee  >>>>> 0.4588
# Very vintage feel  >>>>> 0.0
#   >>>>> 0.0
# Awkward fitting  >>>>> -0.1531
# Cozy casual - perfect for fall  >>>>> 0.6705
# The perfect striped t  >>>>> 0.5719
#   >>>>> 0.0
#   >>>>> 0.0

# %%
undata['total_sentiment_score']= undata['title_sentiment'] + undata['review_sentiment']

# %%
# Golden rule: Save up the original dataframe before encoding!
undata_orig= undata.copy()
undata_orig.shape
# Out:
# (22634, 20)

# %%
undata
# Out:
#        Unnamed: 0  Clothing ID  Age  \
# 0      0           767          33
# 1      1           1080         34
# 2      2           1077         60
# 3      3           1049         50
# 4      4           847          47
# ...   ..           ...          ..
# 23481  23481       1104         34
# 23482  23482       862          48
# 23483  23483       1104         31
# 23484  23484       1084         28
# 23485  23485       1104         52
#
#                                                     Title  \
# 0
# 1
# 2      Some major design flaws
# 3      My favorite buy!
# 4      Flattering shirt
# ...                 ...
# 23481  Great dress for many occasions
# 23482  Wish it was made of cotton
# 23483  Cute, but see through
# 23484  Very cute dress, perfect for summer parties and we
# 23485  Please make more like this one!
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Review Text  \
# 0      Absolutely wonderful - silky and sexy and comfortable
# 1      Love this dress!  it's sooo pretty.  i happened to find it in a store, and i'm glad i did bc i never would have ordered it online bc it's petite.  i bought a petite and am 5'8".  i love the length on me- hits just a little below the knee.  would definitely be a true midi on someone who is truly petite.
# 2      I had such high hopes for this dress and really wanted it to work for me. i initially ordered the petite small (my usual size) but i found this to be outrageously small. so small in fact that i could not zip it up! i reordered it in petite medium, which was just ok. overall, the top half was comfortable and fit nicely, but the bottom half had a very tight under layer and several somewhat cheap (net) over layers. imo, a major design flaw was the net over layer sewn directly into the zipper - it c
# 3      I love, love, love this jumpsuit. it's fun, flirty, and fabulous! every time i wear it, i get nothing but great compliments!
# 4      This shirt is very flattering to all due to the adjustable front tie. it is the perfect length to wear with leggings and it is sleeveless so it pairs well with any cardigan. love this shirt!!!
# ...                                                                                                                                                                                                 ...
# 23481  I was very happy to snag this dress at such a great price! it's very easy to slip on and has a very flattering cut and color combo.
# 23482  It reminds me of maternity clothes. soft, stretchy, shiny material. cut is flattering and drapes nicely. i only found one button to close front... looked awkward. nice long sleeves.\nnot for me but maybe for others. just ok.
# 23483  This fit well, but the top was very see through. this never would have worked for me. i'm glad i was able to try it on in the store and didn't order it online. with different fabric, it would have been great.
# 23484  I bought this dress for a wedding i have this summer, and it's so cute. unfortunately the fit isn't perfect. the medium fits my waist perfectly, but was way too long and too big in the bust and shoulders. if i wanted to spend the money, i could get it tailored, but i just felt like it might not be worth it. side note - this dress was delivered to me with a nordstrom tag on it and i found it much cheaper there after looking!
# 23485  This dress in a lovely platinum is feminine and fits perfectly, easy to wear and comfy, too! highly recommend!
#
#        Rating  Recommended IND  Positive Feedback Count   Division Name  \
# 0      4       1                0                        Initmates
# 1      5       1                4                        General
# 2      3       0                0                        General
# 3      5       1                0                        General Petite
# 4      5       1                6                        General
# ...   ..      ..               ..                            ...
# 23481  5       1                0                        General Petite
# 23482  3       1                0                        General Petite
# 23483  3       0                1                        General Petite
# 23484  3       1                2                        General
# 23485  5       1                22                       General Petite
#
#       Department Name Class Name  Title Word Count  Review Word Count  \
# 0      Intimate        Intimates  0                 8
# 1      Dresses         Dresses    0                 62
# 2      Dresses         Dresses    4                 98
# 3      Bottoms         Pants      3                 22
# 4      Tops            Blouses    2                 36
# ...     ...                ...   ..                 ..
# 23481  Dresses         Dresses    5                 28
# 23482  Tops            Knits      6                 38
# 23483  Dresses         Dresses    4                 42
# 23484  Dresses         Dresses    9                 86
# 23485  Dresses         Dresses    6                 19
#
#                                                                                                                                                                                                                                                                                                            cleantxt  \
# 0      absolutely wonderful silky sexy comfortable
# 1      love dress sooo pretty happened find store glad bc never would ordered online bc petite bought petite love length hits little knee would definitely true midi someone truly petite
# 2      high hopes dress really wanted work initially ordered petite small usual size found outrageously small small fact could zip reordered petite medium overall top half comfortable fit nicely bottom half tight layer several somewhat cheap net layers imo major design flaw net layer sewn directly zipper c
# 3      love love love jumpsuit fun flirty fabulous every time wear get nothing great compliments
# 4      shirt flattering due adjustable front tie perfect length wear leggings sleeveless pairs well cardigan love shirt
# ...                                                                                                                 ...
# 23481  happy snag dress great price easy slip flattering cut color combo
# 23482  reminds maternity clothes soft stretchy shiny material cut flattering drapes nicely found one button close front looked awkward nice long sleeves maybe others ok
# 23483  fit well top see never would worked glad able try store order online different fabric would great
# 23484  bought dress wedding summer cute unfortunately fit perfect medium fits waist perfectly way long big bust shoulders wanted spend money could get tailored felt like might worth side note dress delivered nordstrom tag found much cheaper looking
# 23485  dress lovely platinum feminine fits perfectly easy wear comfy highly recommend
#
#        rev_word_count  unique_word_count new_clothingID  review_sentiment  \
# 0      8               7                  000            0.8932
# 1      62              47                 1080           0.9729
# 2      98              72                 1077           0.9208
# 3      22              20                 000            0.5727
# 4      36              28                 000            0.9291
# ...    ..              ..                 ...               ...
# 23481  28              23                 000            0.9152
# 23482  38              36                 862            0.3919
# 23483  42              36                 000            0.9343
# 23484  86              65                 000            0.6692
# 23485  19              18                 000            0.9358
#
#        title_sentiment  total_sentiment_score
# 0      0.0000           0.8932
# 1      0.0000           0.9729
# 2      0.0000           0.9208
# 3      0.5093           1.0820
# 4      0.3182           1.2473
# ...       ...              ...
# 23481  0.6249           1.5401
# 23482  0.4019           0.7938
# 23483  0.2500           1.1843
# 23484  0.8737           1.5429
# 23485  0.6581           1.5939
#
# [22634 rows x 20 columns]

# %% [markdown]
# ### Feature Encoding and prepping up our data for clustering

# %%
# Dropping text columns- we have already used them to calcuate the total sentiment score

undata.drop(columns=['Unnamed: 0','cleantxt','Review Text','Title','Clothing ID','review_sentiment','title_sentiment','Title Word Count','Review Word Count'], inplace=True)

# %%
# Deciding on categorical columns- object datatype -very slow processing

cat_cols= ['Division Name','Department Name','Class Name','new_clothingID']
for col in cat_cols:
    print(col," has categories:", undata[col].nunique())
    undata[col]= undata[col].astype('category')
# Out:
# Division Name  has categories: 3
# Department Name  has categories: 6
# Class Name  has categories: 20
# new_clothingID  has categories: 29

# %%
undata.head(5)
# Out:
#    Age  Rating  Recommended IND  Positive Feedback Count   Division Name  \
# 0  33   4       1                0                        Initmates
# 1  34   5       1                4                        General
# 2  60   3       0                0                        General
# 3  50   5       1                0                        General Petite
# 4  47   5       1                6                        General
#
#   Department Name Class Name  rev_word_count  unique_word_count  \
# 0  Intimate        Intimates  8               7
# 1  Dresses         Dresses    62              47
# 2  Dresses         Dresses    98              72
# 3  Bottoms         Pants      22              20
# 4  Tops            Blouses    36              28
#
#   new_clothingID  total_sentiment_score
# 0  000            0.8932
# 1  1080           0.9729
# 2  1077           0.9208
# 3  000            1.0820
# 4  000            1.2473

# %%
# %pip install category_encoders
# Out:
# Collecting category_encoders
#   Obtaining dependency information for category_encoders from https://files.pythonhosted.org/packages/63/a8/e2929e8654c15a64504022a8bd1444e748a8bda3450a4868567caf19a6c1/category_encoders-2.8.0-py3-none-any.whl.metadata
#   Downloading category_encoders-2.8.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (1.26.4)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (2.2.3)
# Collecting patsy>=0.5.1 (from category_encoders)
#   Obtaining dependency information for patsy>=0.5.1 from https://files.pythonhosted.org/packages/87/2b/b50d3d08ea0fc419c183a84210571eba005328efa62b6b98bc28e9ead32a/patsy-1.0.1-py2.py3-none-any.whl.metadata
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from category_encoders) (1.13.1)
# Collecting statsmodels>=0.9.0 (from category_encoders)
#   Obtaining dependency information for statsmodels>=0.9.0 from https://files.pythonhosted.org/packages/59/9a/e466a1b887a1441141e52dbcc98152f013d85076576da6eed2357f2016ae/statsmodels-0.14.4-cp312-cp312-win_amd64.whl.metadata
#   Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\k3n\appdata\roaming\python\python312\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.5->category_encoders) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.0.5->category_encoders) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\k3n\appdata\roaming\python\python312\site-packages (from statsmodels>=0.9.0->category_encoders) (24.2)
# Requirement already satisfied: six>=1.5 in c:\users\k3n\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Downloading category_encoders-2.8.0-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.7 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/85.7 kB ? eta -:--:--
#    -------------- ------------------------- 30.7/85.7 kB 435.7 kB/s eta 0:00:01
#    ---------------------------------------- 85.7/85.7 kB 692.3 kB/s eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/232.9 kB ? eta -:--:--
#    --------------------------------------- 232.9/232.9 kB 13.9 MB/s eta 0:00:00
# Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.8 MB 27.2 MB/s eta 0:00:01
#    --------- ------------------------------ 2.4/9.8 MB 25.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.0/9.8 MB 25.2 MB/s eta 0:00:01
#    ------------------- -------------------- 4.8/9.8 MB 25.3 MB/s eta 0:00:01
#    --------------------- ------------------ 5.3/9.8 MB 21.3 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.8 MB 20.3 MB/s eta 0:00:01
#    -------------------------- ------------- 6.5/9.8 MB 18.9 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.8 MB 20.1 MB/s eta 0:00:01
#    ------------------------------------ --- 9.0/9.8 MB 19.9 MB/s eta 0:00:01
#    ------------------------------------- -- 9.3/9.8 MB 18.5 MB/s eta 0:00:01
#    ---------------------------------------  9.8/9.8 MB 17.9 MB/s eta 0:00:01
#    ---------------------------------------  9.8/9.8 MB 17.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 15.3 MB/s eta 0:00:00
# Installing collected packages: patsy, statsmodels, category_encoders
# Successfully installed category_encoders-2.8.0 patsy-1.0.1 statsmodels-0.14.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Binary encoding our categorical columns

import category_encoders as ce
be= ce.BinaryEncoder(cols= cat_cols,drop_invariant=True).fit(undata) 
undata= be.transform(undata)

# %%
from sklearn.pipeline import Pipeline 
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from scipy import stats
from sklearn.cluster import KMeans
import pylab as pl
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
pca_tsne= Pipeline([("pca", PCA(n_components= 0.90, random_state=33)),
                    ("tsne", TSNE(n_components=2,
                                  perplexity= 170,
                                  random_state=33, 
                                  learning_rate= 350, 
                                  n_iter= 5000,
                                  n_iter_without_progress=150,
                                  verbose=1))])
t0 = time.time()
df_pca_tsne_reduced= pca_tsne.fit_transform(undata)
t1 = time.time()

print("pca+tsne took:{:.1f}s ".format(t1-t0))
# Out:
# [t-SNE] Computing 511 nearest neighbors...
# [t-SNE] Indexed 22634 samples in 0.018s...
# [t-SNE] Computed neighbors for 22634 samples in 2.306s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 22634
# [t-SNE] Computed conditional probabilities for sample 2000 / 22634
# [t-SNE] Computed conditional probabilities for sample 3000 / 22634
# [t-SNE] Computed conditional probabilities for sample 4000 / 22634
# [t-SNE] Computed conditional probabilities for sample 5000 / 22634
# [t-SNE] Computed conditional probabilities for sample 6000 / 22634
# [t-SNE] Computed conditional probabilities for sample 7000 / 22634
# [t-SNE] Computed conditional probabilities for sample 8000 / 22634
# [t-SNE] Computed conditional probabilities for sample 9000 / 22634
# [t-SNE] Computed conditional probabilities for sample 10000 / 22634
# [t-SNE] Computed conditional probabilities for sample 11000 / 22634
# [t-SNE] Computed conditional probabilities for sample 12000 / 22634
# [t-SNE] Computed conditional probabilities for sample 13000 / 22634
# [t-SNE] Computed conditional probabilities for sample 14000 / 22634
# [t-SNE] Computed conditional probabilities for sample 15000 / 22634
# [t-SNE] Computed conditional probabilities for sample 16000 / 22634
# [t-SNE] Computed conditional probabilities for sample 17000 / 22634
# [t-SNE] Computed conditional probabilities for sample 18000 / 22634
# [t-SNE] Computed conditional probabilities for sample 19000 / 22634
# [t-SNE] Computed conditional probabilities for sample 20000 / 22634
# [t-SNE] Computed conditional probabilities for sample 21000 / 22634
# [t-SNE] Computed conditional probabilities for sample 22000 / 22634
# [t-SNE] Computed conditional probabilities for sample 22634 / 22634
# [t-SNE] Mean sigma: 2.017375
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.756989
# [t-SNE] KL divergence after 5000 iterations: 0.655662
# pca+tsne took:1391.9s

# %%
sns.set(rc= {'figure.figsize': (13,13)})
sns.scatterplot(x=df_pca_tsne_reduced[:,0], y=df_pca_tsne_reduced[:,1])
plt.show()

# %% [markdown]
# ### Using K-Means Clustering

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pl
import time
from sklearn.cluster import KMeans
from scipy import stats

# Standardizing the data
review_data_std = stats.zscore(df_pca_tsne_reduced)
review_data_std = np.array(review_data_std)

sns.set(rc={'figure.figsize': (7, 7)})
number_of_clusters = range(1, 20)

t0 = time.time()
kmeans = [KMeans(n_clusters=i, max_iter=1000, random_state=33) for i in number_of_clusters]
score = [-1 * kmeans[i].fit(df_pca_tsne_reduced).score(df_pca_tsne_reduced) for i in range(len(kmeans))]
t1 = time.time()

# Plotting the Elbow curve
pl.plot(number_of_clusters, score)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Elbow Curve')
pl.show()

print("Plotting the Elbow curve took: {:.1f}s".format(t1 - t0))
# Out:
# Plotting the Elbow curve took: 0.9s

# %%
k_means_test = KMeans(n_clusters=3, max_iter=1500, random_state=33,verbose=1)

#fitting on your model
-1*k_means_test.fit(df_pca_tsne_reduced).score(df_pca_tsne_reduced)
y_pred= k_means_test.labels_

# Assigning cluster labels to each data point
undata_orig['klabels'] = k_means_test.labels_
# Out:
# Initialization complete
# Iteration 0, inertia 39311124.0.
# Iteration 1, inertia 23270412.0.
# Iteration 2, inertia 21663008.0.
# Iteration 3, inertia 21251440.0.
# Iteration 4, inertia 21136164.0.
# Iteration 5, inertia 21090558.0.
# Iteration 6, inertia 21066324.0.
# Iteration 7, inertia 21053074.0.
# Iteration 8, inertia 21045892.0.
# Iteration 9, inertia 21040458.0.
# Iteration 10, inertia 21036408.0.
# Converged at iteration 10: center shift 0.21228288114070892 within tolerance 0.21936044921875.

# %%
# Analyzing 
size_of_each_cluster= undata_orig.groupby('klabels').size().reset_index()
size_of_each_cluster.columns = ['klabels','number_of_points']
size_of_each_cluster['percentage'] = (size_of_each_cluster['number_of_points']/np.sum(size_of_each_cluster['number_of_points']))*100

print(size_of_each_cluster)
# Out:
#    klabels  number_of_points  percentage
# 0  0        8129              35.914995
# 1  1        7451              32.919502
# 2  2        7054              31.165503

# %%
# palette = sns.hls_palette(3, l=.4, s=.9)

# sns.set(rc= {'figure.figsize': (13,13)})
# sns.scatterplot(df_pca_tsne_reduced[:,0], df_pca_tsne_reduced[:,1], hue= y_pred, legend='full', palette=palette)
# plt.title("t-sne with KMeans labels")
# plt.show()

import seaborn as sns
import matplotlib.pyplot as plt

# Define color palette
palette = sns.hls_palette(3, l=.4, s=.9)

# Set figure size
sns.set(rc={'figure.figsize': (13, 13)})

# Corrected scatter plot function
sns.scatterplot(x=df_pca_tsne_reduced[:, 0], 
                y=df_pca_tsne_reduced[:, 1], 
                hue=y_pred, 
                legend='full', 
                palette=palette)

# Add title and show plot
plt.title("t-SNE with KMeans labels")
plt.show()

# %% [markdown]
# As we can see, the K-Means clusters also closely represents the clusters created by PCA and TSNE. Together it has produced some classic clustering.
# Apart from clustering the reviews together, we would also like to understand 'meaning of each cluster'. This can be achieved via TOPIC MODELING.
#
# Hence, now we will attempt to find the most significant words in each cluster. K-means clustered the articles but did not label the topics. Through topic modeling we will find out what the most important terms for each cluster are. This will add more meaning to the cluster by giving keywords to quickly identify the themes of the cluster.

# %% [markdown]
# ### Topic Modeling- Latent Dirichlet Allocation(LDA)

# %% [markdown]
# For topic modeling, we will use the infamous LDA (Latent Dirichlet Allocation) algorithm. In LDA, each document can be described by a distribution of topics and each topic can be described by a distribution of words.
#
# STEP 1: Preprocessing text - Tokenizing sentences, stopwords removal and lemmatization

# %%
def get_pos_tag(tag):
    """This function is used to get the part-of-speech(POS) for lemmatization"""
    
    if tag.startswith('N') or tag.startswith('J'):
        return wordnet.NOUN
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN #default case

# %%
# nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\K3n\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re
def preprocess(text):
    """ 1. Removes Punctuations
        2. Removes words smaller than 3 letters
        3. Converts into lowercase
        4. Lemmatizes words
        5. Removes Stopwords
    """   
    punctuation= list(string.punctuation)
    doc_tokens= nltk.word_tokenize(text)
    word_tokens= [word.lower() for word in doc_tokens if not (word in punctuation or len(word)<=3)]
    
    # Lemmatize    
    pos_tags=nltk.pos_tag(word_tokens)
#     print(pos_tags)
    doc_words=[wordnet_lemmatizer.lemmatize(word, pos=get_pos_tag(tag)) for word, tag in pos_tags]
    doc_words= [word for word in doc_words if word not in stoplist]
    
    return doc_words

df_clean = undata_orig['Review Text'].apply(preprocess)
df_clean.head()
# Out:
# 0    [absolutely, wonderful, silky, sexy, comfortable]
# 1    [love, dress, sooo, pretty, happen, find, store, glad, never, would, order, online, petite, buy, petite, love, length, hit, little, knee, would, definitely, true, midi, someone, truly, petite]
# 2    [high, hope, dress, really, want, work, initially, order, petite, small, usual, size, find, outrageously, small, small, fact, could, reorder, petite, medium, overall, half, comfortable, nicely, bottom, half, tight, layer, several, somewhat, cheap, layer, major, design, flaw, layer, sewn, directly, zipper]
# 3    [love, love, love, jumpsuit, flirty, fabulous, every, time, wear, nothing, great, compliment]
# 4    [shirt, flatter, adjustable, front, perfect, length, wear, legging, sleeveless, pair, well, cardigan, love, shirt]
# Name: Review Text, dtype: object

# %% [markdown]
# STEP 2: DATA CLEANING- PROCURE ONLY NOUNS AND ADJECTIVES TO OBTAIN MEANINGFUL TOPICS

# %%
# Adding business stopwords to exclude

common_terms= ["wear","look","ordered","color","purchase","order"]

stoplist= stoplist+ common_terms

# %%
# Tried multiple parts of speech and obtained best topic results using Nouns and Adjectives!
def get_nouns_adjs(series):
    
    " Topic Modeling using only nouns and adjectives"
    
    pos_tags= nltk.pos_tag(series)
    all_adj_nouns= [word for (word, tag) in pos_tags if (tag=="NN" or tag=="NNS" or tag=="JJ")] 
    return all_adj_nouns

df_nouns_adj = df_clean.apply(get_nouns_adjs)

# %% [markdown]
# Step 3: Add bigrams to your corpus using Word2vec model from gensim

# %%
# Importing gensim related libraries
import gensim
from gensim.models.ldamulticore import LdaMulticore
from gensim.corpora import Dictionary
from gensim.models import Phrases
from collections import Counter
from gensim.models import Word2Vec

# %%
docs= list(df_nouns_adj)
phrases = gensim.models.Phrases(docs, min_count=10, threshold=20)
bigram_model = gensim.models.phrases.Phraser(phrases)
# Out:
# INFO:gensim.models.phrases:collecting all words and their counts
# INFO:gensim.models.phrases:PROGRESS: at sentence #0, processed 0 words and 0 word types
# INFO:gensim.models.phrases:PROGRESS: at sentence #10000, processed 174223 words and 95983 word types
# INFO:gensim.models.phrases:PROGRESS: at sentence #20000, processed 349739 words and 162150 word types
# INFO:gensim.models.phrases:collected 177542 token types (unigram + bigrams) from a corpus of 396082 words and 22634 sentences
# INFO:gensim.models.phrases:merged Phrases<177542 vocab, min_count=10, threshold=20, max_vocab_size=40000000>
# INFO:gensim.utils:Phrases lifecycle event {'msg': 'built Phrases<177542 vocab, min_count=10, threshold=20, max_vocab_size=40000000> in 0.54s', 'datetime': '2025-02-07T22:50:55.479579', 'gensim': '4.3.3', 'python': '3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26100-SP0', 'event': 'created'}
# INFO:gensim.models.phrases:exporting phrases from Phrases<177542 vocab, min_count=10, threshold=20, max_vocab_size=40000000>
# INFO:gensim.utils:FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<203 phrases, min_count=10, threshold=20> from Phrases<177542 vocab, min_count=10, threshold=20, max_vocab_size=40000000> in 0.30s', 'datetime': '2025-02-07T22:50:55.780291', 'gensim': '4.3.3', 'python': '3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26100-SP0', 'event': 'created'}

# %%
def make_bigrams(texts):
    return [bigram_model[doc] for doc in texts]

# Form Bigrams
data_words_bigrams = make_bigrams(docs)

# %%
# Checkout most frequent bigrams :
bigram_counter1= Counter()
for key in phrases.vocab.keys():
    if key not in stopwords.words('english'):
        if len(str(key).split('_'))>1:
            bigram_counter1[key]+=phrases.vocab[key]

for key, counts in bigram_counter1.most_common(20):
    print(key,">>>>", counts)
# Out:
# true_size >>>> 1317
# look_great >>>> 735
# size_small >>>> 728
# order_size >>>> 628
# size_size >>>> 524
# usual_size >>>> 496
# fabric_soft >>>> 391
# many_compliment >>>> 362
# order_small >>>> 349
# soft_comfortable >>>> 349
# love_dress >>>> 349
# skinny_jean >>>> 339
# regular_size >>>> 332
# wear_size >>>> 318
# material_soft >>>> 316
# super_soft >>>> 312
# size_large >>>> 300
# dress_look >>>> 293
# petite_size >>>> 286
# fit_true >>>> 278

# %% [markdown]
# Feeding the bigrams into a Word2Vec model produces more meaningful bigrams

# %%
from gensim.models import Word2Vec

w2vmodel = Word2Vec(bigram_model[docs], vector_size=100, sg=1, hs=1, seed=33, epochs=35)
bigram_counter = Counter()

for key in w2vmodel.wv.key_to_index.keys():
    if key not in stoplist:
        if len(str(key).split("_")) > 1:
            bigram_counter[key] += w2vmodel.wv.get_vecattr(key, "count")

for key, counts in bigram_counter.most_common(30):
    print(key,">>>>> " ,counts)
# Out:
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 170473 words, keeping 8159 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #20000, processed 342092 words, keeping 11820 word types
# INFO:gensim.models.word2vec:collected 12700 word types from a corpus of 387404 raw words and 22634 sentences
# INFO:gensim.models.word2vec:Creating a fresh vocabulary
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 3280 unique words (25.83% of original 12700, drops 9420)', 'datetime': '2025-02-07T22:53:04.732240', 'gensim': '4.3.3', 'python': '3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26100-SP0', 'event': 'prepare_vocab'}
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 373898 word corpus (96.51% of original 387404, drops 13506)', 'datetime': '2025-02-07T22:53:04.733243', 'gensim': '4.3.3', 'python': '3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26100-SP0', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 12700 items
# INFO:gensim.models.word2vec:sample=0.001 downsamples 73 most-common words
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 288395.87266668235 word corpus (77.1%% of prior 373898)', 'datetime': '2025-02-07T22:53:04.753211', 'gensim': '4.3.3', 'python': '3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26100-SP0', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:constructing a huffman tree from 3280 words
# INFO:gensim.models.word2vec:built huffman tree with maximum node depth 16
# INFO:gensim.models.word2vec:estimated required memory for 3280 words and 100 dimensions: 6232000 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:gensim.utils:Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2025-02-07T22:53:04.922848', 'gensim': '4.3.3', 'python': '3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26100-SP0', 'event': 'build_vocab'}
# WARNING:gensim.models.word2vec:Both hierarchical softmax and negative sampling are activated. This is probably a mistake. You should set either 'hs=0' or 'negative=0' to disable one of them.
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'training model with 3 workers on 3280 vocabulary and 100 features, using sg=1 hs=1 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2025-02-07T22:53:04.922848', 'gensim': '4.3.3', 'python': '3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26100-SP0', 'event': 'train'}
# INFO:gensim.models.word2vec:EPOCH 0 - PROGRESS: at 69.89% examples, 197195 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 0: training on 387404 raw words (288551 effective words) took 1.4s, 203807 effective words/s
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 69.87% examples, 193806 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1: training on 387404 raw words (288526 effective words) took 1.6s, 185612 effective words/s
# INFO:gensim.models.word2vec:EPOCH 2 - PROGRESS: at 69.89% examples, 196255 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 2: training on 387404 raw words (288336 effective words) took 1.5s, 194682 effective words/s
# INFO:gensim.models.word2vec:EPOCH 3 - PROGRESS: at 41.48% examples, 118423 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 3: training on 387404 raw words (288280 effective words) took 1.7s, 166926 effective words/s
# INFO:gensim.models.word2vec:EPOCH 4 - PROGRESS: at 75.00% examples, 213833 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 4: training on 387404 raw words (288638 effective words) took 1.3s, 217962 effective words/s
# INFO:gensim.models.word2vec:EPOCH 5 - PROGRESS: at 72.46% examples, 201940 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 5: training on 387404 raw words (288632 effective words) took 1.4s, 203192 effective words/s
# INFO:gensim.models.word2vec:EPOCH 6 - PROGRESS: at 69.89% examples, 194840 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 6: training on 387404 raw words (288517 effective words) took 1.5s, 193778 effective words/s
# INFO:gensim.models.word2vec:EPOCH 7 - PROGRESS: at 77.52% examples, 218051 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 7: training on 387404 raw words (288417 effective words) took 1.4s, 212071 effective words/s
# INFO:gensim.models.word2vec:EPOCH 8 - PROGRESS: at 77.52% examples, 216576 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 8: training on 387404 raw words (288529 effective words) took 1.3s, 220355 effective words/s
# INFO:gensim.models.word2vec:EPOCH 9 - PROGRESS: at 82.61% examples, 229501 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 9: training on 387404 raw words (288171 effective words) took 1.3s, 229823 effective words/s
# INFO:gensim.models.word2vec:EPOCH 10 - PROGRESS: at 77.52% examples, 217252 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 10: training on 387404 raw words (288522 effective words) took 1.3s, 217360 effective words/s
# INFO:gensim.models.word2vec:EPOCH 11 - PROGRESS: at 80.07% examples, 228208 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 11: training on 387404 raw words (288400 effective words) took 1.3s, 224248 effective words/s
# INFO:gensim.models.word2vec:EPOCH 12 - PROGRESS: at 85.16% examples, 235800 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 12: training on 387404 raw words (288528 effective words) took 1.2s, 234960 effective words/s
# INFO:gensim.models.word2vec:EPOCH 13 - PROGRESS: at 77.52% examples, 218507 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 13: training on 387404 raw words (288583 effective words) took 1.3s, 221787 effective words/s
# INFO:gensim.models.word2vec:EPOCH 14 - PROGRESS: at 75.00% examples, 209397 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 14: training on 387404 raw words (288309 effective words) took 1.4s, 210367 effective words/s
# INFO:gensim.models.word2vec:EPOCH 15 - PROGRESS: at 75.00% examples, 213814 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 15: training on 387404 raw words (288484 effective words) took 1.4s, 207863 effective words/s
# INFO:gensim.models.word2vec:EPOCH 16 - PROGRESS: at 80.07% examples, 230063 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 16: training on 387404 raw words (288308 effective words) took 1.2s, 238432 effective words/s
# INFO:gensim.models.word2vec:EPOCH 17 - PROGRESS: at 80.07% examples, 229587 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 17: training on 387404 raw words (288547 effective words) took 1.2s, 239234 effective words/s
# INFO:gensim.models.word2vec:EPOCH 18 - PROGRESS: at 72.46% examples, 206956 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 18: training on 387404 raw words (288466 effective words) took 1.4s, 213074 effective words/s
# INFO:gensim.models.word2vec:EPOCH 19 - PROGRESS: at 80.07% examples, 230627 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 19: training on 387404 raw words (288396 effective words) took 1.3s, 230714 effective words/s
# INFO:gensim.models.word2vec:EPOCH 20 - PROGRESS: at 80.07% examples, 227350 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 20: training on 387404 raw words (288423 effective words) took 1.3s, 228577 effective words/s
# INFO:gensim.models.word2vec:EPOCH 21 - PROGRESS: at 72.46% examples, 206255 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 21: training on 387404 raw words (288395 effective words) took 1.4s, 212879 effective words/s
# INFO:gensim.models.word2vec:EPOCH 22 - PROGRESS: at 80.07% examples, 228424 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 22: training on 387404 raw words (288539 effective words) took 1.3s, 226037 effective words/s
# INFO:gensim.models.word2vec:EPOCH 23 - PROGRESS: at 80.07% examples, 225499 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 23: training on 387404 raw words (288251 effective words) took 1.3s, 223935 effective words/s
# INFO:gensim.models.word2vec:EPOCH 24 - PROGRESS: at 80.07% examples, 229944 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 24: training on 387404 raw words (288383 effective words) took 1.3s, 217758 effective words/s
# INFO:gensim.models.word2vec:EPOCH 25 - PROGRESS: at 75.00% examples, 214452 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 25: training on 387404 raw words (288517 effective words) took 1.2s, 233110 effective words/s
# INFO:gensim.models.word2vec:EPOCH 26 - PROGRESS: at 85.16% examples, 236083 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 26: training on 387404 raw words (288779 effective words) took 1.2s, 233286 effective words/s
# INFO:gensim.models.word2vec:EPOCH 27 - PROGRESS: at 77.52% examples, 222473 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 27: training on 387404 raw words (288401 effective words) took 1.2s, 234674 effective words/s
# INFO:gensim.models.word2vec:EPOCH 28 - PROGRESS: at 82.61% examples, 232876 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 28: training on 387404 raw words (288445 effective words) took 1.2s, 232743 effective words/s
# INFO:gensim.models.word2vec:EPOCH 29 - PROGRESS: at 80.07% examples, 227346 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 29: training on 387404 raw words (288540 effective words) took 1.3s, 223164 effective words/s
# INFO:gensim.models.word2vec:EPOCH 30 - PROGRESS: at 77.52% examples, 221322 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 30: training on 387404 raw words (288589 effective words) took 1.3s, 224738 effective words/s
# INFO:gensim.models.word2vec:EPOCH 31 - PROGRESS: at 77.52% examples, 221285 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 31: training on 387404 raw words (288333 effective words) took 1.3s, 222291 effective words/s
# INFO:gensim.models.word2vec:EPOCH 32 - PROGRESS: at 82.61% examples, 229743 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 32: training on 387404 raw words (288498 effective words) took 1.3s, 218643 effective words/s
# INFO:gensim.models.word2vec:EPOCH 33 - PROGRESS: at 75.00% examples, 211111 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 33: training on 387404 raw words (288364 effective words) took 1.4s, 212167 effective words/s
# INFO:gensim.models.word2vec:EPOCH 34 - PROGRESS: at 75.00% examples, 214340 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 34: training on 387404 raw words (288480 effective words) took 1.3s, 217555 effective words/s
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'training on 13559140 raw words (10096077 effective words) took 47.1s, 214536 effective words/s', 'datetime': '2025-02-07T22:53:51.980212', 'gensim': '4.3.3', 'python': '3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26100-SP0', 'event': 'train'}
# INFO:gensim.utils:Word2Vec lifecycle event {'params': 'Word2Vec<vocab=3280, vector_size=100, alpha=0.025>', 'datetime': '2025-02-07T22:53:51.980212', 'gensim': '4.3.3', 'python': '3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26100-SP0', 'event': 'created'}
# many_compliment >>>>>  362
# skinny_jean >>>>>  339
# body_type >>>>>  231
# sale_price >>>>>  220
# full_price >>>>>  209
# first_time >>>>>  204
# local_retailer >>>>>  169
# broad_shoulder >>>>>  157
# local_store >>>>>  149
# base_review >>>>>  137
# light_weight >>>>>  131
# worth_price >>>>>  128
# cami_underneath >>>>>  118
# previous_review >>>>>  110
# spring_summer >>>>>  108
# last_year >>>>>  101
# read_review >>>>>  97
# lot_compliment >>>>>  97
# pencil_skirt >>>>>  90
# right_place >>>>>  89
# athletic_build >>>>>  89
# denim_jacket >>>>>  88
# fall_winter >>>>>  88
# price_point >>>>>  79
# right_amount >>>>>  79
# real_life >>>>>  76
# tank_underneath >>>>>  75
# hand_wash >>>>>  72
# ton_compliment >>>>>  71
# hourglass_figure >>>>>  63

# %% [markdown]
# Checkout some cool stuff from the bigram model!

# %%
# MostOften mentioned along with the word 'pregnant'
w2vmodel.wv.most_similar(positive= ['pregnant'])
# Out:
# [('baby_bump', 0.5624832510948181),
#  ('pregnancy', 0.534929096698761),
#  ('maternity', 0.5096177458763123),
#  ('nurse', 0.4948658049106598),
#  ('trimester', 0.4783053994178772),
#  ('month_pregnant', 0.47429731488227844),
#  ('twin', 0.4563334882259369),
#  ('tent', 0.4454760253429413),
#  ('ginormous', 0.43197134137153625),
#  ('accommodate', 0.42133593559265137)]

# %%
# Which color is to 'work' as 'white' is to 'wedding'
w2vmodel.wv.most_similar(['work','white'], ['wedding'], topn=5)
# Out:
# [('black', 0.5938723087310791),
#  ('stark', 0.4356849491596222),
#  ('navy', 0.4345398247241974),
#  ('crop', 0.42971643805503845),
#  ('slack', 0.4189128577709198)]

# %%
w2vmodel.wv.most_similar(['price','steal'], ['discount'], topn=5)
# Out:
# [('sale', 0.4283299148082733),
#  ('quality', 0.40957584977149963),
#  ('steep', 0.4047645926475525),
#  ('sale_price', 0.3917081654071808),
#  ('loving', 0.37020233273506165)]

# %%
# What is a 'deal_breaker', if 'quality'is 'worth_penny' 
w2vmodel.wv.most_similar(positive=["deal_breaker","quality"], negative=["worth_penny"], topn=3)
# Out:
# [('fabric', 0.43493202328681946),
#  ('price_point', 0.3791366219520569),
#  ('scratchy', 0.36080116033554077)]

# %% [markdown]
# Step 4: Create a dictionary and corpus for input to our LDA model. Filter out the most common and uncommon words.

# %%
dictionary= Dictionary(data_words_bigrams)

# Filter out words that occur less than 20 documents, or more than 50% of the documents.
dictionary.filter_extremes(no_below=20, no_above=0.6)
corpus = [dictionary.doc2bow(doc) for doc in docs]

print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# INFO:gensim.corpora.dictionary:adding document #0 to Dictionary<0 unique tokens: []>
# INFO:gensim.corpora.dictionary:adding document #10000 to Dictionary<8159 unique tokens: ['comfortable', 'sexy', 'silky', 'wonderful', 'dress']...>
# INFO:gensim.corpora.dictionary:adding document #20000 to Dictionary<11820 unique tokens: ['comfortable', 'sexy', 'silky', 'wonderful', 'dress']...>
# INFO:gensim.corpora.dictionary:built Dictionary<12700 unique tokens: ['comfortable', 'sexy', 'silky', 'wonderful', 'dress']...> from 22634 documents (total 387404 corpus positions)
# INFO:gensim.utils:Dictionary lifecycle event {'msg': "built Dictionary<12700 unique tokens: ['comfortable', 'sexy', 'silky', 'wonderful', 'dress']...> from 22634 documents (total 387404 corpus positions)", 'datetime': '2025-02-07T22:58:52.891605', 'gensim': '4.3.3', 'python': '3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26100-SP0', 'event': 'created'}
# INFO:gensim.corpora.dictionary:discarding 11172 tokens: [('narrowing', 1), ('basket', 12), ('darkler', 1), ('ejans', 1), ('jkeep', 1), ('matvehd', 1), ('mintue', 1), ('msallet', 1), ('oops', 1), ('say', 14)]...
# INFO:gensim.corpora.dictionary:keeping 1528 tokens which were in no less than 20 and no more than 13580 (=60.0%) documents
# INFO:gensim.corpora.dictionary:resulting dictionary: Dictionary<1528 unique tokens: ['comfortable', 'sexy', 'silky', 'wonderful', 'dress']...>
# Number of unique tokens: 1528
# Number of documents: 22634

# %% [markdown]
# Step 5: Train your LDA model- Topic Modeling

# %%
from gensim.models.ldamulticore import LdaMulticore

t0= time.time()
passes= 150
np.random.seed(1) # setting up random seed to get the same results
ldamodel= LdaMulticore(corpus, 
                    id2word=dictionary, 
                    num_topics=4, 
#                   alpha='asymmetric', 
                    chunksize= 4000, 
                    batch= True,
                    minimum_probability=0.001,
                    iterations=350,
                    passes=passes)                    

t1= time.time()
print("time for",passes," passes: ",(t1-t0)," seconds")
# Out:
# INFO:gensim.models.ldamodel:using symmetric alpha at 0.25
# INFO:gensim.models.ldamodel:using symmetric eta at 0.25
# INFO:gensim.models.ldamodel:using serial LDA version on this node
# INFO:gensim.models.ldamulticore:running batch LDA training, 4 topics, 150 passes over the supplied corpus of 22634 documents, updating every 22634 documents, evaluating every ~22634 documents, iterating 350x with a convergence threshold of 0.001000
# INFO:gensim.models.ldamulticore:training LDA model using 7 processes
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 0, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.038*"dress" + 0.033*"size" + 0.018*"small" + 0.017*"look" + 0.016*"color" + 0.014*"wear" + 0.012*"fabric" + 0.011*"short" + 0.011*"love" + 0.010*"comfortable"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.024*"color" + 0.023*"size" + 0.021*"order" + 0.017*"wear" + 0.016*"fabric" + 0.015*"look" + 0.014*"large" + 0.013*"nice" + 0.013*"dress" + 0.013*"soft"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.033*"dress" + 0.030*"size" + 0.024*"great" + 0.022*"wear" + 0.018*"look" + 0.015*"cute" + 0.014*"order" + 0.013*"color" + 0.012*"little" + 0.012*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.032*"dress" + 0.027*"color" + 0.025*"size" + 0.021*"great" + 0.018*"look" + 0.016*"love" + 0.014*"fabric" + 0.013*"order" + 0.011*"beautiful" + 0.011*"wear"
# INFO:gensim.models.ldamodel:topic diff=1.807191, rho=1.000000
# INFO:gensim.models.ldamodel:-6.201 per-word bound, 73.6 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 1, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.041*"dress" + 0.035*"size" + 0.019*"small" + 0.016*"look" + 0.015*"color" + 0.014*"wear" + 0.012*"short" + 0.011*"fabric" + 0.011*"love" + 0.010*"comfortable"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.024*"color" + 0.024*"size" + 0.022*"order" + 0.016*"fabric" + 0.016*"wear" + 0.016*"look" + 0.015*"large" + 0.014*"shirt" + 0.014*"nice" + 0.013*"soft"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.033*"dress" + 0.029*"size" + 0.026*"great" + 0.023*"wear" + 0.019*"look" + 0.015*"cute" + 0.013*"order" + 0.012*"little" + 0.012*"color" + 0.012*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.033*"dress" + 0.027*"color" + 0.025*"size" + 0.021*"great" + 0.018*"look" + 0.016*"love" + 0.015*"fabric" + 0.012*"order" + 0.012*"beautiful" + 0.010*"wear"
# INFO:gensim.models.ldamodel:topic diff=0.079253, rho=0.361350
# INFO:gensim.models.ldamodel:-6.191 per-word bound, 73.1 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 2, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.043*"dress" + 0.036*"size" + 0.019*"small" + 0.016*"look" + 0.015*"color" + 0.014*"wear" + 0.012*"short" + 0.011*"fabric" + 0.010*"love" + 0.010*"comfortable"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.025*"size" + 0.024*"color" + 0.023*"order" + 0.017*"fabric" + 0.016*"look" + 0.016*"shirt" + 0.016*"large" + 0.015*"wear" + 0.014*"nice" + 0.013*"soft"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.032*"dress" + 0.028*"size" + 0.027*"great" + 0.024*"wear" + 0.019*"look" + 0.016*"cute" + 0.012*"order" + 0.012*"soft" + 0.012*"little" + 0.012*"jean"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.034*"dress" + 0.027*"color" + 0.024*"size" + 0.021*"great" + 0.018*"look" + 0.016*"love" + 0.015*"fabric" + 0.012*"beautiful" + 0.012*"order" + 0.010*"fit"
# INFO:gensim.models.ldamodel:topic diff=0.076174, rho=0.339843
# INFO:gensim.models.ldamodel:-6.181 per-word bound, 72.6 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 3, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.045*"dress" + 0.038*"size" + 0.020*"small" + 0.015*"look" + 0.014*"color" + 0.014*"wear" + 0.012*"short" + 0.010*"fabric" + 0.010*"love" + 0.010*"waist"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.026*"size" + 0.024*"color" + 0.024*"order" + 0.017*"shirt" + 0.017*"look" + 0.017*"fabric" + 0.016*"large" + 0.014*"nice" + 0.014*"wear" + 0.014*"small"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.031*"dress" + 0.029*"great" + 0.026*"size" + 0.025*"wear" + 0.019*"look" + 0.016*"cute" + 0.014*"jean" + 0.013*"soft" + 0.012*"sweater" + 0.012*"comfortable"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.036*"dress" + 0.027*"color" + 0.024*"size" + 0.020*"great" + 0.018*"look" + 0.016*"love" + 0.016*"fabric" + 0.013*"beautiful" + 0.011*"order" + 0.010*"quality"
# INFO:gensim.models.ldamodel:topic diff=0.073161, rho=0.321770
# INFO:gensim.models.ldamodel:-6.171 per-word bound, 72.1 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 4, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.047*"dress" + 0.039*"size" + 0.020*"small" + 0.015*"look" + 0.014*"wear" + 0.014*"color" + 0.012*"short" + 0.011*"waist" + 0.010*"petite" + 0.010*"love"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.026*"size" + 0.024*"order" + 0.024*"color" + 0.018*"shirt" + 0.018*"look" + 0.017*"fabric" + 0.016*"large" + 0.015*"small" + 0.014*"nice" + 0.013*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.031*"great" + 0.030*"dress" + 0.026*"wear" + 0.025*"size" + 0.019*"look" + 0.016*"cute" + 0.015*"jean" + 0.013*"soft" + 0.013*"comfortable" + 0.013*"perfect"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.037*"dress" + 0.028*"color" + 0.023*"size" + 0.019*"great" + 0.018*"look" + 0.016*"fabric" + 0.016*"love" + 0.013*"beautiful" + 0.011*"order" + 0.011*"quality"
# INFO:gensim.models.ldamodel:topic diff=0.070171, rho=0.306303
# INFO:gensim.models.ldamodel:-6.161 per-word bound, 71.6 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 5, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.049*"dress" + 0.041*"size" + 0.020*"small" + 0.014*"wear" + 0.014*"look" + 0.014*"color" + 0.012*"short" + 0.011*"waist" + 0.011*"petite" + 0.010*"love"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.027*"size" + 0.024*"order" + 0.024*"color" + 0.019*"shirt" + 0.018*"look" + 0.017*"fabric" + 0.016*"large" + 0.016*"small" + 0.014*"nice" + 0.013*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.032*"great" + 0.029*"dress" + 0.027*"wear" + 0.023*"size" + 0.018*"look" + 0.016*"jean" + 0.016*"cute" + 0.014*"soft" + 0.014*"comfortable" + 0.013*"perfect"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.039*"dress" + 0.028*"color" + 0.023*"size" + 0.019*"great" + 0.018*"look" + 0.017*"fabric" + 0.016*"love" + 0.014*"beautiful" + 0.011*"quality" + 0.011*"order"
# INFO:gensim.models.ldamodel:topic diff=0.066797, rho=0.292873
# INFO:gensim.models.ldamodel:-6.153 per-word bound, 71.2 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 6, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.050*"dress" + 0.042*"size" + 0.020*"small" + 0.014*"wear" + 0.014*"look" + 0.013*"color" + 0.012*"short" + 0.012*"waist" + 0.012*"petite" + 0.010*"perfect"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.028*"size" + 0.025*"order" + 0.023*"color" + 0.019*"shirt" + 0.019*"look" + 0.017*"fabric" + 0.017*"large" + 0.016*"small" + 0.014*"nice" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.034*"great" + 0.028*"wear" + 0.028*"dress" + 0.022*"size" + 0.018*"look" + 0.018*"jean" + 0.016*"cute" + 0.014*"comfortable" + 0.014*"soft" + 0.014*"perfect"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.040*"dress" + 0.028*"color" + 0.022*"size" + 0.018*"look" + 0.018*"great" + 0.017*"fabric" + 0.016*"love" + 0.014*"beautiful" + 0.011*"quality" + 0.010*"price"
# INFO:gensim.models.ldamodel:topic diff=0.063647, rho=0.281066
# INFO:gensim.models.ldamodel:-6.145 per-word bound, 70.8 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 7, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.052*"dress" + 0.044*"size" + 0.020*"small" + 0.014*"wear" + 0.013*"look" + 0.013*"waist" + 0.013*"color" + 0.012*"short" + 0.012*"petite" + 0.010*"perfect"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.028*"size" + 0.025*"order" + 0.023*"color" + 0.020*"shirt" + 0.019*"look" + 0.017*"small" + 0.017*"large" + 0.017*"fabric" + 0.014*"nice" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.035*"great" + 0.029*"wear" + 0.027*"dress" + 0.021*"size" + 0.019*"jean" + 0.018*"look" + 0.016*"cute" + 0.015*"comfortable" + 0.015*"perfect" + 0.015*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.041*"dress" + 0.028*"color" + 0.021*"size" + 0.018*"look" + 0.018*"fabric" + 0.017*"great" + 0.016*"love" + 0.015*"beautiful" + 0.011*"quality" + 0.011*"price"
# INFO:gensim.models.ldamodel:topic diff=0.060539, rho=0.270582
# INFO:gensim.models.ldamodel:-6.139 per-word bound, 70.5 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 8, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.053*"dress" + 0.045*"size" + 0.021*"small" + 0.014*"wear" + 0.014*"waist" + 0.013*"look" + 0.013*"petite" + 0.012*"short" + 0.012*"color" + 0.010*"length"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.029*"size" + 0.025*"order" + 0.023*"color" + 0.020*"shirt" + 0.020*"look" + 0.018*"small" + 0.017*"large" + 0.017*"fabric" + 0.014*"little" + 0.014*"nice"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.036*"great" + 0.029*"wear" + 0.026*"dress" + 0.020*"size" + 0.019*"jean" + 0.018*"look" + 0.016*"comfortable" + 0.015*"cute" + 0.015*"perfect" + 0.015*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.042*"dress" + 0.028*"color" + 0.021*"size" + 0.018*"look" + 0.018*"fabric" + 0.017*"great" + 0.015*"love" + 0.015*"beautiful" + 0.012*"quality" + 0.011*"price"
# INFO:gensim.models.ldamodel:topic diff=0.057598, rho=0.261189
# INFO:gensim.models.ldamodel:-6.133 per-word bound, 70.2 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 9, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.054*"dress" + 0.046*"size" + 0.021*"small" + 0.014*"waist" + 0.014*"wear" + 0.013*"petite" + 0.013*"look" + 0.012*"short" + 0.012*"color" + 0.010*"order"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.029*"size" + 0.024*"order" + 0.022*"color" + 0.020*"shirt" + 0.020*"look" + 0.019*"small" + 0.017*"large" + 0.016*"fabric" + 0.014*"little" + 0.013*"nice"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.036*"great" + 0.030*"wear" + 0.025*"dress" + 0.020*"jean" + 0.019*"size" + 0.018*"look" + 0.016*"comfortable" + 0.016*"perfect" + 0.015*"soft" + 0.015*"cute"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.044*"dress" + 0.029*"color" + 0.020*"size" + 0.018*"look" + 0.018*"fabric" + 0.016*"great" + 0.016*"beautiful" + 0.015*"love" + 0.012*"quality" + 0.012*"price"
# INFO:gensim.models.ldamodel:topic diff=0.055075, rho=0.252711
# INFO:gensim.models.ldamodel:-6.128 per-word bound, 70.0 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 10, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 10, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 10, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 10, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 10, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 10, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.055*"dress" + 0.047*"size" + 0.021*"small" + 0.015*"waist" + 0.014*"wear" + 0.013*"petite" + 0.012*"look" + 0.012*"short" + 0.011*"color" + 0.011*"order"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.029*"size" + 0.024*"order" + 0.022*"color" + 0.021*"shirt" + 0.021*"look" + 0.019*"small" + 0.017*"large" + 0.016*"fabric" + 0.014*"little" + 0.014*"sweater"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.037*"great" + 0.030*"wear" + 0.024*"dress" + 0.021*"jean" + 0.018*"size" + 0.018*"look" + 0.017*"comfortable" + 0.016*"perfect" + 0.016*"soft" + 0.015*"color"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.045*"dress" + 0.029*"color" + 0.020*"size" + 0.018*"fabric" + 0.018*"look" + 0.016*"beautiful" + 0.016*"great" + 0.015*"love" + 0.012*"price" + 0.012*"quality"
# INFO:gensim.models.ldamodel:topic diff=0.052519, rho=0.245009
# INFO:gensim.models.ldamodel:-6.124 per-word bound, 69.7 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 11, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 11, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 11, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 11, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 11, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 11, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.055*"dress" + 0.048*"size" + 0.021*"small" + 0.015*"waist" + 0.014*"wear" + 0.014*"petite" + 0.012*"look" + 0.012*"short" + 0.011*"order" + 0.011*"color"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.030*"size" + 0.024*"order" + 0.022*"color" + 0.021*"shirt" + 0.021*"look" + 0.020*"small" + 0.017*"large" + 0.016*"fabric" + 0.014*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.038*"great" + 0.031*"wear" + 0.023*"dress" + 0.021*"jean" + 0.018*"look" + 0.017*"size" + 0.017*"comfortable" + 0.017*"perfect" + 0.016*"soft" + 0.015*"color"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.045*"dress" + 0.029*"color" + 0.019*"size" + 0.019*"fabric" + 0.018*"look" + 0.016*"beautiful" + 0.015*"great" + 0.015*"love" + 0.012*"price" + 0.012*"quality"
# INFO:gensim.models.ldamodel:topic diff=0.050344, rho=0.237970
# INFO:gensim.models.ldamodel:-6.120 per-word bound, 69.6 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 12, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 12, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 12, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 12, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 12, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 12, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.056*"dress" + 0.049*"size" + 0.021*"small" + 0.016*"waist" + 0.014*"petite" + 0.014*"wear" + 0.012*"short" + 0.012*"look" + 0.012*"order" + 0.011*"length"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.030*"size" + 0.024*"order" + 0.022*"color" + 0.021*"shirt" + 0.021*"look" + 0.020*"small" + 0.017*"large" + 0.016*"fabric" + 0.014*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.038*"great" + 0.031*"wear" + 0.023*"dress" + 0.022*"jean" + 0.018*"look" + 0.017*"comfortable" + 0.017*"perfect" + 0.017*"size" + 0.016*"soft" + 0.016*"color"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.046*"dress" + 0.029*"color" + 0.019*"fabric" + 0.019*"size" + 0.018*"look" + 0.017*"beautiful" + 0.015*"great" + 0.015*"love" + 0.012*"price" + 0.012*"quality"
# INFO:gensim.models.ldamodel:topic diff=0.048245, rho=0.231506
# INFO:gensim.models.ldamodel:-6.117 per-word bound, 69.4 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 13, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 13, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 13, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 13, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 13, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 13, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.056*"dress" + 0.050*"size" + 0.021*"small" + 0.016*"waist" + 0.015*"petite" + 0.014*"wear" + 0.012*"order" + 0.012*"short" + 0.012*"look" + 0.011*"length"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.030*"size" + 0.024*"order" + 0.021*"shirt" + 0.021*"look" + 0.021*"color" + 0.020*"small" + 0.017*"large" + 0.016*"fabric" + 0.014*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.039*"great" + 0.031*"wear" + 0.022*"jean" + 0.022*"dress" + 0.018*"comfortable" + 0.017*"look" + 0.017*"perfect" + 0.016*"color" + 0.016*"soft" + 0.016*"size"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.047*"dress" + 0.029*"color" + 0.019*"fabric" + 0.018*"look" + 0.018*"size" + 0.017*"beautiful" + 0.014*"love" + 0.014*"great" + 0.013*"price" + 0.012*"quality"
# INFO:gensim.models.ldamodel:topic diff=0.046615, rho=0.225541
# INFO:gensim.models.ldamodel:-6.114 per-word bound, 69.3 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 14, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 14, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 14, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 14, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 14, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 14, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.057*"dress" + 0.051*"size" + 0.021*"small" + 0.017*"waist" + 0.015*"petite" + 0.014*"wear" + 0.013*"order" + 0.012*"short" + 0.012*"look" + 0.011*"length"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.030*"size" + 0.024*"order" + 0.022*"shirt" + 0.022*"look" + 0.021*"color" + 0.021*"small" + 0.018*"large" + 0.016*"fabric" + 0.014*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.039*"great" + 0.031*"wear" + 0.023*"jean" + 0.022*"dress" + 0.018*"comfortable" + 0.017*"perfect" + 0.017*"look" + 0.017*"color" + 0.016*"soft" + 0.016*"love"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.048*"dress" + 0.029*"color" + 0.019*"fabric" + 0.018*"look" + 0.018*"size" + 0.017*"beautiful" + 0.014*"love" + 0.014*"great" + 0.013*"price" + 0.012*"quality"
# INFO:gensim.models.ldamodel:topic diff=0.044804, rho=0.220014
# INFO:gensim.models.ldamodel:-6.112 per-word bound, 69.2 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 15, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 15, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 15, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 15, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 15, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 15, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.057*"dress" + 0.051*"size" + 0.020*"small" + 0.017*"waist" + 0.015*"petite" + 0.014*"wear" + 0.013*"order" + 0.012*"short" + 0.012*"length" + 0.012*"look"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.030*"size" + 0.024*"order" + 0.022*"look" + 0.022*"shirt" + 0.021*"small" + 0.021*"color" + 0.018*"large" + 0.016*"fabric" + 0.014*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.039*"great" + 0.032*"wear" + 0.023*"jean" + 0.021*"dress" + 0.018*"comfortable" + 0.018*"perfect" + 0.017*"look" + 0.017*"color" + 0.017*"soft" + 0.017*"love"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.048*"dress" + 0.029*"color" + 0.020*"fabric" + 0.018*"look" + 0.018*"beautiful" + 0.017*"size" + 0.014*"love" + 0.014*"great" + 0.013*"price" + 0.012*"quality"
# INFO:gensim.models.ldamodel:topic diff=0.043226, rho=0.214875
# INFO:gensim.models.ldamodel:-6.110 per-word bound, 69.1 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 16, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 16, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 16, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 16, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 16, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 16, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.057*"dress" + 0.052*"size" + 0.020*"small" + 0.017*"waist" + 0.016*"petite" + 0.014*"order" + 0.013*"wear" + 0.012*"short" + 0.012*"length" + 0.011*"look"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.030*"size" + 0.023*"order" + 0.022*"look" + 0.022*"shirt" + 0.021*"small" + 0.021*"color" + 0.018*"large" + 0.016*"fabric" + 0.015*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.039*"great" + 0.032*"wear" + 0.023*"jean" + 0.021*"dress" + 0.018*"comfortable" + 0.018*"perfect" + 0.017*"color" + 0.017*"look" + 0.017*"love" + 0.017*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.049*"dress" + 0.030*"color" + 0.020*"fabric" + 0.018*"look" + 0.018*"beautiful" + 0.017*"size" + 0.014*"love" + 0.013*"great" + 0.013*"price" + 0.012*"quality"
# INFO:gensim.models.ldamodel:topic diff=0.041701, rho=0.210080
# INFO:gensim.models.ldamodel:-6.108 per-word bound, 69.0 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 17, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 17, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 17, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 17, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 17, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 17, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.057*"dress" + 0.053*"size" + 0.020*"small" + 0.018*"waist" + 0.016*"petite" + 0.014*"order" + 0.013*"wear" + 0.012*"short" + 0.012*"length" + 0.011*"look"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.030*"size" + 0.023*"order" + 0.022*"look" + 0.022*"shirt" + 0.022*"small" + 0.021*"color" + 0.018*"large" + 0.016*"fabric" + 0.015*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.040*"great" + 0.032*"wear" + 0.024*"jean" + 0.020*"dress" + 0.019*"comfortable" + 0.018*"perfect" + 0.018*"color" + 0.017*"look" + 0.017*"love" + 0.017*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.049*"dress" + 0.030*"color" + 0.020*"fabric" + 0.018*"look" + 0.018*"beautiful" + 0.017*"size" + 0.014*"love" + 0.013*"price" + 0.013*"great" + 0.012*"quality"
# INFO:gensim.models.ldamodel:topic diff=0.040324, rho=0.205592
# INFO:gensim.models.ldamodel:-6.106 per-word bound, 68.9 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 18, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 18, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 18, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 18, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 18, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 18, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.058*"dress" + 0.053*"size" + 0.020*"small" + 0.018*"waist" + 0.016*"petite" + 0.014*"order" + 0.013*"wear" + 0.012*"length" + 0.012*"short" + 0.011*"look"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.030*"size" + 0.023*"order" + 0.022*"look" + 0.022*"shirt" + 0.022*"small" + 0.020*"color" + 0.018*"large" + 0.016*"fabric" + 0.015*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.040*"great" + 0.032*"wear" + 0.024*"jean" + 0.020*"dress" + 0.019*"comfortable" + 0.018*"perfect" + 0.018*"color" + 0.017*"love" + 0.017*"look" + 0.017*"soft"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.050*"dress" + 0.030*"color" + 0.020*"fabric" + 0.018*"beautiful" + 0.018*"look" + 0.016*"size" + 0.014*"love" + 0.014*"price" + 0.013*"great" + 0.012*"quality"
# INFO:gensim.models.ldamodel:topic diff=0.038964, rho=0.201380
# INFO:gensim.models.ldamodel:-6.104 per-word bound, 68.8 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 19, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 19, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 19, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 19, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 19, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 19, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.058*"dress" + 0.054*"size" + 0.020*"small" + 0.018*"waist" + 0.017*"petite" + 0.015*"order" + 0.013*"wear" + 0.012*"length" + 0.012*"short" + 0.011*"look"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.030*"size" + 0.023*"order" + 0.022*"look" + 0.022*"shirt" + 0.022*"small" + 0.020*"color" + 0.018*"large" + 0.016*"fabric" + 0.015*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.040*"great" + 0.032*"wear" + 0.024*"jean" + 0.020*"dress" + 0.019*"comfortable" + 0.019*"perfect" + 0.018*"color" + 0.018*"love" + 0.017*"soft" + 0.017*"look"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.050*"dress" + 0.030*"color" + 0.020*"fabric" + 0.018*"beautiful" + 0.018*"look" + 0.016*"size" + 0.014*"price" + 0.014*"love" + 0.013*"great" + 0.012*"quality"
# INFO:gensim.models.ldamodel:topic diff=0.037676, rho=0.197417
# INFO:gensim.models.ldamodel:-6.103 per-word bound, 68.7 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 20, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 20, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 20, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 20, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 20, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 20, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.058*"dress" + 0.054*"size" + 0.020*"small" + 0.019*"waist" + 0.017*"petite" + 0.015*"order" + 0.013*"wear" + 0.013*"length" + 0.012*"short" + 0.011*"look"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.030*"size" + 0.023*"order" + 0.023*"small" + 0.023*"look" + 0.022*"shirt" + 0.020*"color" + 0.018*"large" + 0.016*"fabric" + 0.015*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.040*"great" + 0.032*"wear" + 0.024*"jean" + 0.020*"dress" + 0.019*"comfortable" + 0.019*"perfect" + 0.019*"color" + 0.018*"love" + 0.017*"soft" + 0.017*"look"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.050*"dress" + 0.030*"color" + 0.020*"fabric" + 0.019*"beautiful" + 0.018*"look" + 0.016*"size" + 0.014*"price" + 0.014*"love" + 0.012*"great" + 0.012*"quality"
# INFO:gensim.models.ldamodel:topic diff=0.036440, rho=0.193679
# INFO:gensim.models.ldamodel:-6.101 per-word bound, 68.7 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 21, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 21, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 21, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 21, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 21, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 21, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.058*"dress" + 0.055*"size" + 0.020*"small" + 0.019*"waist" + 0.017*"petite" + 0.015*"order" + 0.013*"wear" + 0.013*"length" + 0.012*"short" + 0.011*"look"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.023*"small" + 0.023*"look" + 0.023*"shirt" + 0.023*"order" + 0.020*"color" + 0.018*"large" + 0.016*"fabric" + 0.015*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.040*"great" + 0.033*"wear" + 0.025*"jean" + 0.019*"comfortable" + 0.019*"dress" + 0.019*"color" + 0.019*"perfect" + 0.018*"love" + 0.017*"soft" + 0.017*"look"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.051*"dress" + 0.030*"color" + 0.020*"fabric" + 0.019*"beautiful" + 0.018*"look" + 0.015*"size" + 0.014*"price" + 0.013*"love" + 0.012*"quality" + 0.012*"great"
# INFO:gensim.models.ldamodel:topic diff=0.035291, rho=0.190145
# INFO:gensim.models.ldamodel:-6.100 per-word bound, 68.6 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 22, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 22, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 22, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 22, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 22, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 22, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.058*"dress" + 0.055*"size" + 0.020*"small" + 0.019*"waist" + 0.017*"petite" + 0.016*"order" + 0.013*"wear" + 0.013*"length" + 0.012*"short" + 0.011*"look"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.023*"small" + 0.023*"look" + 0.023*"shirt" + 0.022*"order" + 0.020*"color" + 0.018*"large" + 0.016*"fabric" + 0.015*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.041*"great" + 0.033*"wear" + 0.025*"jean" + 0.020*"comfortable" + 0.019*"color" + 0.019*"dress" + 0.019*"perfect" + 0.018*"love" + 0.017*"soft" + 0.017*"look"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.051*"dress" + 0.030*"color" + 0.020*"fabric" + 0.019*"beautiful" + 0.018*"look" + 0.015*"size" + 0.014*"price" + 0.013*"love" + 0.012*"quality" + 0.012*"great"
# INFO:gensim.models.ldamodel:topic diff=0.034245, rho=0.186798
# INFO:gensim.models.ldamodel:-6.099 per-word bound, 68.5 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 23, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 23, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 23, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 23, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 23, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 23, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.058*"dress" + 0.056*"size" + 0.020*"small" + 0.019*"waist" + 0.017*"petite" + 0.016*"order" + 0.013*"length" + 0.013*"wear" + 0.012*"short" + 0.011*"look"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.023*"small" + 0.023*"look" + 0.023*"shirt" + 0.022*"order" + 0.020*"color" + 0.018*"large" + 0.016*"fabric" + 0.015*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.041*"great" + 0.033*"wear" + 0.025*"jean" + 0.020*"comfortable" + 0.019*"color" + 0.019*"perfect" + 0.019*"dress" + 0.018*"love" + 0.018*"soft" + 0.017*"look"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.051*"dress" + 0.030*"color" + 0.020*"fabric" + 0.019*"beautiful" + 0.018*"look" + 0.015*"size" + 0.014*"price" + 0.013*"love" + 0.012*"quality" + 0.012*"great"
# INFO:gensim.models.ldamodel:topic diff=0.033153, rho=0.183622
# INFO:gensim.models.ldamodel:-6.098 per-word bound, 68.5 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 24, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 24, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 24, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 24, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 24, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 24, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.058*"dress" + 0.056*"size" + 0.020*"small" + 0.020*"waist" + 0.018*"petite" + 0.016*"order" + 0.013*"length" + 0.013*"wear" + 0.012*"short" + 0.011*"look"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.023*"small" + 0.023*"look" + 0.023*"shirt" + 0.022*"order" + 0.019*"color" + 0.018*"large" + 0.016*"fabric" + 0.015*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.041*"great" + 0.033*"wear" + 0.025*"jean" + 0.020*"comfortable" + 0.020*"color" + 0.019*"perfect" + 0.019*"dress" + 0.018*"love" + 0.018*"soft" + 0.017*"look"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.052*"dress" + 0.030*"color" + 0.020*"fabric" + 0.019*"beautiful" + 0.018*"look" + 0.015*"size" + 0.014*"price" + 0.013*"love" + 0.012*"quality" + 0.012*"great"
# INFO:gensim.models.ldamodel:topic diff=0.032124, rho=0.180603
# INFO:gensim.models.ldamodel:-6.097 per-word bound, 68.4 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 25, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 25, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 25, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 25, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 25, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 25, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.058*"dress" + 0.057*"size" + 0.020*"small" + 0.020*"waist" + 0.018*"petite" + 0.017*"order" + 0.013*"length" + 0.013*"wear" + 0.012*"short" + 0.011*"look"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.023*"small" + 0.023*"look" + 0.023*"shirt" + 0.022*"order" + 0.019*"color" + 0.018*"large" + 0.016*"fabric" + 0.015*"sweater" + 0.014*"little"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.041*"great" + 0.033*"wear" + 0.025*"jean" + 0.020*"comfortable" + 0.020*"color" + 0.019*"perfect" + 0.019*"love" + 0.018*"dress" + 0.018*"soft" + 0.017*"look"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.052*"dress" + 0.030*"color" + 0.020*"fabric" + 0.019*"beautiful" + 0.018*"look" + 0.014*"size" + 0.014*"price" + 0.013*"love" + 0.012*"quality" + 0.011*"great"
# INFO:gensim.models.ldamodel:topic diff=0.031177, rho=0.177728
# INFO:gensim.models.ldamodel:-6.096 per-word bound, 68.4 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 26, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 26, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 26, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 26, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 26, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 26, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.058*"dress" + 0.057*"size" + 0.020*"small" + 0.020*"waist" + 0.018*"petite" + 0.017*"order" + 0.013*"length" + 0.013*"wear" + 0.012*"short" + 0.011*"look"
# ...
# INFO:gensim.models.ldamulticore:PROGRESS: pass 141, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.065*"size" + 0.057*"dress" + 0.023*"waist" + 0.023*"order" + 0.022*"small" + 0.021*"petite" + 0.015*"length" + 0.012*"short" + 0.012*"look" + 0.012*"regular"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.025*"small" + 0.025*"shirt" + 0.024*"look" + 0.018*"large" + 0.018*"order" + 0.017*"sweater" + 0.017*"color" + 0.016*"fabric" + 0.014*"medium"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.044*"great" + 0.036*"wear" + 0.028*"jean" + 0.025*"color" + 0.024*"comfortable" + 0.023*"perfect" + 0.022*"love" + 0.019*"soft" + 0.017*"pant" + 0.016*"dress"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.057*"dress" + 0.034*"color" + 0.022*"beautiful" + 0.020*"fabric" + 0.017*"look" + 0.016*"price" + 0.013*"sale" + 0.012*"quality" + 0.011*"person" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.003576, rho=0.082294
# INFO:gensim.models.ldamodel:-6.078 per-word bound, 67.5 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 142, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 142, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 142, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 142, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 142, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 142, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.065*"size" + 0.057*"dress" + 0.023*"waist" + 0.023*"order" + 0.022*"small" + 0.021*"petite" + 0.015*"length" + 0.012*"short" + 0.012*"look" + 0.012*"regular"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.025*"small" + 0.025*"shirt" + 0.024*"look" + 0.018*"large" + 0.018*"order" + 0.017*"sweater" + 0.017*"color" + 0.016*"fabric" + 0.014*"medium"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.044*"great" + 0.036*"wear" + 0.028*"jean" + 0.025*"color" + 0.024*"comfortable" + 0.023*"perfect" + 0.022*"love" + 0.019*"soft" + 0.017*"pant" + 0.016*"dress"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.057*"dress" + 0.034*"color" + 0.022*"beautiful" + 0.020*"fabric" + 0.017*"look" + 0.016*"price" + 0.013*"sale" + 0.012*"quality" + 0.011*"person" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.003539, rho=0.082017
# INFO:gensim.models.ldamodel:-6.078 per-word bound, 67.5 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 143, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 143, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 143, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 143, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 143, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 143, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.065*"size" + 0.057*"dress" + 0.023*"waist" + 0.023*"order" + 0.022*"small" + 0.021*"petite" + 0.015*"length" + 0.012*"short" + 0.012*"look" + 0.012*"regular"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.025*"small" + 0.025*"shirt" + 0.024*"look" + 0.018*"large" + 0.018*"order" + 0.017*"sweater" + 0.017*"color" + 0.016*"fabric" + 0.014*"medium"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.044*"great" + 0.036*"wear" + 0.028*"jean" + 0.025*"color" + 0.024*"comfortable" + 0.023*"perfect" + 0.022*"love" + 0.019*"soft" + 0.017*"pant" + 0.016*"dress"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.057*"dress" + 0.034*"color" + 0.022*"beautiful" + 0.020*"fabric" + 0.017*"look" + 0.016*"price" + 0.013*"sale" + 0.012*"quality" + 0.011*"person" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.003512, rho=0.081743
# INFO:gensim.models.ldamodel:-6.078 per-word bound, 67.5 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 144, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 144, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 144, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 144, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 144, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 144, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.065*"size" + 0.057*"dress" + 0.023*"waist" + 0.023*"order" + 0.022*"small" + 0.021*"petite" + 0.015*"length" + 0.012*"short" + 0.012*"look" + 0.012*"regular"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.025*"small" + 0.025*"shirt" + 0.024*"look" + 0.018*"large" + 0.018*"order" + 0.017*"sweater" + 0.017*"color" + 0.016*"fabric" + 0.014*"medium"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.044*"great" + 0.036*"wear" + 0.028*"jean" + 0.025*"color" + 0.024*"comfortable" + 0.023*"perfect" + 0.022*"love" + 0.019*"soft" + 0.017*"pant" + 0.016*"dress"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.057*"dress" + 0.034*"color" + 0.022*"beautiful" + 0.020*"fabric" + 0.017*"look" + 0.016*"price" + 0.013*"sale" + 0.012*"quality" + 0.011*"person" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.003471, rho=0.081471
# INFO:gensim.models.ldamodel:-6.078 per-word bound, 67.5 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 145, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 145, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 145, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 145, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 145, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 145, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.065*"size" + 0.057*"dress" + 0.023*"waist" + 0.023*"order" + 0.023*"small" + 0.021*"petite" + 0.015*"length" + 0.012*"short" + 0.012*"look" + 0.012*"regular"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.025*"small" + 0.025*"shirt" + 0.024*"look" + 0.018*"large" + 0.018*"order" + 0.017*"sweater" + 0.017*"color" + 0.016*"fabric" + 0.014*"medium"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.044*"great" + 0.036*"wear" + 0.028*"jean" + 0.025*"color" + 0.024*"comfortable" + 0.023*"perfect" + 0.022*"love" + 0.019*"soft" + 0.017*"pant" + 0.016*"dress"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.057*"dress" + 0.034*"color" + 0.022*"beautiful" + 0.020*"fabric" + 0.017*"look" + 0.016*"price" + 0.013*"sale" + 0.012*"quality" + 0.011*"person" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.003426, rho=0.081202
# INFO:gensim.models.ldamodel:-6.078 per-word bound, 67.5 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 146, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 146, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 146, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 146, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 146, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 146, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.065*"size" + 0.057*"dress" + 0.023*"waist" + 0.023*"order" + 0.023*"small" + 0.021*"petite" + 0.015*"length" + 0.012*"short" + 0.012*"look" + 0.012*"regular"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.025*"small" + 0.025*"shirt" + 0.024*"look" + 0.018*"large" + 0.018*"order" + 0.017*"sweater" + 0.017*"color" + 0.016*"fabric" + 0.014*"medium"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.044*"great" + 0.036*"wear" + 0.028*"jean" + 0.025*"color" + 0.024*"comfortable" + 0.023*"perfect" + 0.022*"love" + 0.019*"soft" + 0.017*"pant" + 0.016*"dress"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.057*"dress" + 0.034*"color" + 0.022*"beautiful" + 0.020*"fabric" + 0.017*"look" + 0.016*"price" + 0.013*"sale" + 0.012*"quality" + 0.011*"person" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.003393, rho=0.080936
# INFO:gensim.models.ldamodel:-6.078 per-word bound, 67.5 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 147, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 147, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 147, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 147, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 147, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 147, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.065*"size" + 0.056*"dress" + 0.023*"waist" + 0.023*"order" + 0.023*"small" + 0.021*"petite" + 0.015*"length" + 0.012*"look" + 0.012*"short" + 0.012*"regular"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.025*"small" + 0.025*"shirt" + 0.024*"look" + 0.018*"large" + 0.018*"order" + 0.017*"sweater" + 0.017*"color" + 0.016*"fabric" + 0.014*"medium"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.044*"great" + 0.036*"wear" + 0.028*"jean" + 0.025*"color" + 0.024*"comfortable" + 0.023*"perfect" + 0.022*"love" + 0.019*"soft" + 0.017*"pant" + 0.016*"dress"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.057*"dress" + 0.034*"color" + 0.022*"beautiful" + 0.020*"fabric" + 0.017*"look" + 0.016*"price" + 0.013*"sale" + 0.012*"quality" + 0.011*"person" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.003352, rho=0.080672
# INFO:gensim.models.ldamodel:-6.077 per-word bound, 67.5 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 148, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 148, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 148, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 148, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 148, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 148, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.065*"size" + 0.056*"dress" + 0.023*"waist" + 0.023*"order" + 0.023*"small" + 0.021*"petite" + 0.015*"length" + 0.012*"look" + 0.012*"short" + 0.012*"regular"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.025*"small" + 0.025*"shirt" + 0.024*"look" + 0.018*"large" + 0.018*"order" + 0.017*"sweater" + 0.017*"color" + 0.016*"fabric" + 0.014*"medium"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.044*"great" + 0.036*"wear" + 0.028*"jean" + 0.025*"color" + 0.024*"comfortable" + 0.023*"perfect" + 0.022*"love" + 0.019*"soft" + 0.017*"pant" + 0.016*"dress"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.057*"dress" + 0.034*"color" + 0.022*"beautiful" + 0.020*"fabric" + 0.017*"look" + 0.016*"price" + 0.013*"sale" + 0.012*"quality" + 0.011*"person" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.003316, rho=0.080411
# INFO:gensim.models.ldamodel:-6.077 per-word bound, 67.5 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.models.ldamulticore:PROGRESS: pass 149, dispatched chunk #0 = documents up to #4000/22634, outstanding queue size 1
# INFO:gensim.models.ldamulticore:PROGRESS: pass 149, dispatched chunk #1 = documents up to #8000/22634, outstanding queue size 2
# INFO:gensim.models.ldamulticore:PROGRESS: pass 149, dispatched chunk #2 = documents up to #12000/22634, outstanding queue size 3
# INFO:gensim.models.ldamulticore:PROGRESS: pass 149, dispatched chunk #3 = documents up to #16000/22634, outstanding queue size 4
# INFO:gensim.models.ldamulticore:PROGRESS: pass 149, dispatched chunk #4 = documents up to #20000/22634, outstanding queue size 5
# INFO:gensim.models.ldamulticore:PROGRESS: pass 149, dispatched chunk #5 = documents up to #22634/22634, outstanding queue size 6
# INFO:gensim.models.ldamodel:topic #0 (0.250): 0.065*"size" + 0.056*"dress" + 0.023*"waist" + 0.023*"order" + 0.023*"small" + 0.021*"petite" + 0.015*"length" + 0.012*"look" + 0.012*"short" + 0.012*"regular"
# INFO:gensim.models.ldamodel:topic #1 (0.250): 0.031*"size" + 0.025*"small" + 0.025*"shirt" + 0.024*"look" + 0.018*"large" + 0.018*"order" + 0.017*"sweater" + 0.017*"color" + 0.016*"fabric" + 0.014*"medium"
# INFO:gensim.models.ldamodel:topic #2 (0.250): 0.044*"great" + 0.036*"wear" + 0.028*"jean" + 0.025*"color" + 0.024*"comfortable" + 0.023*"perfect" + 0.022*"love" + 0.019*"soft" + 0.017*"pant" + 0.016*"dress"
# INFO:gensim.models.ldamodel:topic #3 (0.250): 0.057*"dress" + 0.034*"color" + 0.022*"beautiful" + 0.020*"fabric" + 0.017*"look" + 0.016*"price" + 0.013*"sale" + 0.012*"quality" + 0.011*"person" + 0.011*"love"
# INFO:gensim.models.ldamodel:topic diff=0.003277, rho=0.080152
# INFO:gensim.models.ldamodel:-6.077 per-word bound, 67.5 perplexity estimate based on a held-out corpus of 2634 documents with 42711 words
# INFO:gensim.utils:LdaMulticore lifecycle event {'msg': 'trained LdaMulticore<num_terms=1528, num_topics=4, decay=0.5, chunksize=4000> in 798.33s', 'datetime': '2025-02-07T23:12:11.762767', 'gensim': '4.3.3', 'python': '3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]', 'platform': 'Windows-11-10.0.26100-SP0', 'event': 'created'}
# time for 150  passes:  798.3447768688202  seconds

# %% [markdown]
# STEP 5: Here are the topics

# %%
ldamodel.show_topics(num_words=25, formatted=False)
# Out:
# [(0,
#   [('size', 0.064882256),
#    ('dress', 0.0564678),
#    ('waist', 0.022956138),
#    ('order', 0.02279217),
#    ('small', 0.0225529),
#    ('petite', 0.021426246),
#    ('length', 0.014977502),
#    ('look', 0.012012553),
#    ('short', 0.011988183),
#    ('regular', 0.011573129),
#    ('skirt', 0.01156949),
#    ('fit', 0.011538234),
#    ('fabric', 0.011445051),
#    ('large', 0.010851666),
#    ('wear', 0.010434514),
#    ('little', 0.010371048),
#    ('great', 0.009639843),
#    ('work', 0.008281751),
#    ('hip', 0.00818379),
#    ('medium', 0.007618178),
#    ('perfect', 0.007598568),
#    ('flatter', 0.0071454006),
#    ('bust', 0.0070947567),
#    ('right', 0.0070520416),
#    ('love', 0.006672177)]),
#  (1,
#   [('size', 0.031048529),
#    ('small', 0.024986107),
#    ('shirt', 0.024724714),
#    ('look', 0.02381583),
#    ('large', 0.018013297),
#    ('order', 0.017750196),
#    ('sweater', 0.017432606),
#    ('color', 0.016696384),
#    ('fabric', 0.015744444),
#    ('medium', 0.014396889),
#    ('little', 0.014305528),
#    ('cute', 0.013742185),
#    ('soft', 0.011814927),
#    ('material', 0.010949459),
#    ('nice', 0.0108805075),
#    ('arm', 0.010425456),
#    ('wear', 0.010080855),
#    ('love', 0.009856037),
#    ('shoulder', 0.009171556),
#    ('fit', 0.008601144),
#    ('sleeve', 0.0084394),
#    ('front', 0.008237136),
#    ('top', 0.008075846),
#    ('button', 0.00778512),
#    ('detail', 0.0074884356)]),
#  (2,
#   [('great', 0.043653533),
#    ('wear', 0.035724282),
#    ('jean', 0.028252844),
#    ('color', 0.024621611),
#    ('comfortable', 0.023720616),
#    ('perfect', 0.023495382),
#    ('love', 0.021647431),
#    ('soft', 0.01919988),
#    ('pant', 0.016714076),
#    ('dress', 0.015793948),
#    ('look', 0.015567752),
#    ('pair', 0.0145425545),
#    ('summer', 0.011566472),
#    ('compliment', 0.01108617),
#    ('cute', 0.010932787),
#    ('casual', 0.010786208),
#    ('black', 0.010443503),
#    ('work', 0.010370307),
#    ('jacket', 0.010086033),
#    ('purchase', 0.009767416),
#    ('super', 0.009552569),
#    ('fall', 0.009417306),
#    ('nice', 0.008298393),
#    ('time', 0.008256136),
#    ('many', 0.008125635)]),
#  (3,
#   [('dress', 0.057021488),
#    ('color', 0.03422392),
#    ('beautiful', 0.021753838),
#    ('fabric', 0.0200179),
#    ('look', 0.017290294),
#    ('price', 0.015687367),
#    ('sale', 0.013387784),
#    ('quality', 0.012289521),
#    ('person', 0.011368249),
#    ('love', 0.011047119),
#    ('picture', 0.010987398),
#    ('store', 0.010762975),
#    ('online', 0.010658498),
#    ('much', 0.00907159),
#    ('material', 0.008569808),
#    ('retailer', 0.008361301),
#    ('design', 0.008063177),
#    ('wear', 0.008021645),
#    ('line', 0.007968973),
#    ('order', 0.0077755903),
#    ('gorgeous', 0.0074812323),
#    ('size', 0.0072939885),
#    ('blue', 0.0071613765),
#    ('purchase', 0.0071409685),
#    ('great', 0.0071399766)])]

# %%
lda_corpus= ldamodel[corpus]

# %%
all_topics = ldamodel.get_document_topics(corpus)
num_docs = len(all_topics)

all_topics_csr= gensim.matutils.corpus2csc(all_topics)
all_topics_numpy= all_topics_csr.T.toarray()

major_topic= [np.argmax(arr) for arr in all_topics_numpy]
undata_orig['major_lda_topic']= major_topic

# %%
undata_orig.head(1)
# Out:
#    Unnamed: 0  Clothing ID  Age Title  \
# 0  0           767          33
#
#                                              Review Text  Rating  \
# 0  Absolutely wonderful - silky and sexy and comfortable  4
#
#    Recommended IND  Positive Feedback Count Division Name Department Name  \
# 0  1                0                        Initmates     Intimate
#
#    ... Review Word Count                                     cleantxt  \
# 0  ...  8                 absolutely wonderful silky sexy comfortable
#
#    rev_word_count unique_word_count  new_clothingID  review_sentiment  \
# 0  8               7                 000             0.8932
#
#   title_sentiment  total_sentiment_score  klabels  major_lda_topic
# 0  0.0             0.8932                 2        3
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Analyze K-means Clustering against Topic Labeling

# %%
sns.set(rc= {'figure.figsize': (5,3)})
sns.set_style('darkgrid')

undata_orig.major_lda_topic.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='major_lda_topic'>

# %%
undata_orig.groupby(['klabels'])['major_lda_topic'].value_counts(ascending=False, normalize=True)
# Out:
# klabels  major_lda_topic
# 0        0                  0.316890
#          1                  0.296469
#          3                  0.226965
#          2                  0.159675
# 1        1                  0.288015
#          2                  0.252584
#          0                  0.247618
#          3                  0.211784
# 2        2                  0.393536
#          1                  0.239722
#          3                  0.208818
#          0                  0.157925
# Name: proportion, dtype: float64

# %% [markdown]
# ### Deriving Conclusions- Looking at the data

# %%
num_cols= ['Age','Positive_Feedback_Count','rev_word_count', 'unique_word_count','total_sentiment_score']

cat_cols= ['major_lda_topic','Division_Name','Department_Name','Class_Name']

cluster1= undata_orig.loc[(undata_orig.klabels==0)]
cluster2= undata_orig.loc[(undata_orig.klabels==1)]
cluster3= undata_orig.loc[(undata_orig.klabels==2)]

# %%
cluster1.columns= cluster1.columns.str.replace(" ", "_")
cluster2.columns= cluster2.columns.str.replace(" ", "_")
cluster3.columns= cluster3.columns.str.replace(" ", "_")

# %% [markdown]
# ### Cluster 1 Visualization

# %%
pd.DataFrame((cluster1.Rating.value_counts()*100)/undata_orig.Rating.value_counts()).plot(kind='bar')
# Out:
# <Axes: xlabel='Rating'>

# %%
print('Visualizing numerical features:')
for i, col in enumerate(num_cols):
    plt.figure(i)
    sns.distplot(cluster1[col])
# Out:
# Visualizing numerical features:

# %%
print('Visualizing categorical features:')
for i, col in enumerate(cat_cols):
    plt.figure(i)
    chart= sns.countplot(cluster1[col], order= cluster1[col].value_counts().index)
    chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Visualizing categorical features:

# %% [markdown]
# ### Cluster 2 Visualization

# %%
print('Visualizing numerical features:')
for i, col in enumerate(num_cols):
    plt.figure(i)
    sns.distplot(cluster2[col])
# Out:
# Visualizing numerical features:

# %%
pd.DataFrame((cluster2.Rating.value_counts()*100)/undata_orig.Rating.value_counts()).plot(kind='bar')
# Out:
# <Axes: xlabel='Rating'>

# %%
print('Visualizing categorical features:')
for i, col in enumerate(cat_cols):
    plt.figure(i)
    chart= sns.countplot(cluster2[col], order= cluster2[col].value_counts().index)
    chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Visualizing categorical features:

# %% [markdown]
# ### Cluster 3 Visualization

# %%
pd.DataFrame((cluster3.Rating.value_counts()*100)/undata_orig.Rating.value_counts()).plot(kind='bar')
# Out:
# <Axes: xlabel='Rating'>

# %%
print('Visualizing numerical features:')
for i, col in enumerate(num_cols):
    plt.figure(i)
    sns.distplot(cluster3[col])
# Out:
# Visualizing numerical features:

# %%
print('Visualizing categorical features:')
for i, col in enumerate(cat_cols):
    plt.figure(i)
    chart= sns.countplot(cluster3[col], order= cluster3[col].value_counts().index)
    chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Visualizing categorical features:

# %%
topics = ldamodel.show_topics(num_words=25, formatted=False)

# %%
# %pip install WordCloud
# Out:
# Collecting WordCloud
#   Obtaining dependency information for WordCloud from https://files.pythonhosted.org/packages/b9/74/6a15f68f59bc90032bfcf62eca796a5675be95e1aaf84f7861e1bfcfa8e5/wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from WordCloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from WordCloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from WordCloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\k3n\appdata\roaming\python\python312\site-packages (from matplotlib->WordCloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\k3n\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\k3n\appdata\roaming\python\python312\site-packages (from matplotlib->WordCloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\k3n\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.17.0)
# Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl (301 kB)
#    ---------------------------------------- 0.0/301.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.2 kB ? eta -:--:--
#    ---------- ----------------------------- 81.9/301.2 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 301.2/301.2 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: WordCloud
# Successfully installed WordCloud-1.9.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wordcloud_cli.exe is installed in 'c:\Users\K3n\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stoplist,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=100,
                  colormap='tab100',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

fig, axes = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Analysis and observation

# %% [markdown]
# ### Understanding Clusters:

# %% [markdown]
# <b>Cluster 1 contains reviews having:</b>
#
# Young/Middle-aged women(age group 25-40) who have written descriptive reviews(40-80 words).
# Reviews are related to topic 3(31%),2,1.
#
# <b>Cluster 2 contains reviews having:</b>
#
# Middle/Elderly women(age group 35-60) who have written rather precise reviews(50-80 words).
# Reviews are related to topic 2(~40%),3,1.
#
# <b>Cluster 3 contains reviews having:</b>
#
# All age groups inclusive(25-60) who have written very detailed reviews(80-110 words).
# Reviews are related to topic 3(~37%),0,1.

# %% [markdown]
# ### Understanding Topics:

# %% [markdown]
# <b>topic 0 contains reviews having:</b>
#
# Reviews are related to Dress, pants, skirts.<br>
# Concerning stuff: oder, look, small, petite, short, length, size.
#
# <b>topic 1 contains reviews having:</b>
#
# Reviews are related to bottomwear such as Shirt, fabric<br>
# Concerning stuff: Size, look, little, white, wear, cute, color, soft
#
# <b>topic 2 contains reviews having:</b>
#
# Reviews are related to topwear such as Dress, sweater. <br>
# Concerning stuff: love, great, comfortable, wear perfect, summer, soft, color
#
# <b>topic 3 contains reviews having:</b>
#
# Reviews are related to dress related comments<br>
# Concerning stuff: Color, size, fabric, online, large, order, small, beautiful, look

# %% [markdown]
# # References

# %% [markdown]
# https://www.kaggle.com/nicapotato/womens-ecommerce-clothing-reviews

# %% [markdown]
# https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/

# %% [markdown]
# https://medium.com/bexs-test/text-clustering-with-k-means-a039d84a941b

# %% [markdown]
# https://medium.com/@yanlinc/how-to-build-a-lda-topic-model-using-from-text-601cdcbfd3a6

# %%
# !jupyter nbconvert --to html Womens_Clothing_Review.ipynb
# Out:
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: kernel kernelspec migrate run troubleshoot trust
#
# Jupyter command `jupyter-nbconvert` not found.
